# %% [markdown]
# # Data Cleaning and EDA

# %% [markdown]
# ## Initial Overview

# %% [markdown]
# ### Read in elections contribution data

# %%
# libraries
import pandas as pd
import numpy as np
import re
from rapidfuzz import process

# %%
# read in the csv
df = pd.read_csv('data/contributions/od_cntrbtn_audt_e.csv')
# Out:
# C:\Users\cjyu9\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3548: DtypeWarning: Columns (4,5,7,8,10,25,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#   Political Entity  Recipient ID             Recipient Recipient last name  \
# 0      ﻿Candidates          4716  Béchard, Bruno-Marie             Béchard
# 1       Candidates          4716  Béchard, Bruno-Marie             Béchard
# 2       Candidates          4716  Béchard, Bruno-Marie             Béchard
# 3       Candidates          4716  Béchard, Bruno-Marie             Béchard
# 4       Candidates          4716  Béchard, Bruno-Marie             Béchard
#
#   Recipient first name Recipient middle initial Political Party of Recipient  \
# 0          Bruno-Marie                      NaN      Liberal Party of Canada
# 1          Bruno-Marie                      NaN      Liberal Party of Canada
# 2          Bruno-Marie                      NaN      Liberal Party of Canada
# 3          Bruno-Marie                      NaN      Liberal Party of Canada
# 4          Bruno-Marie                      NaN      Liberal Party of Canada
#
#   Electoral District        Electoral event Fiscal/Election date  ...  \
# 0         Sherbrooke  38th general election           2004-06-28  ...
# 1         Sherbrooke  38th general election           2004-06-28  ...
# 2         Sherbrooke  38th general election           2004-06-28  ...
# 3         Sherbrooke  38th general election           2004-06-28  ...
# 4         Sherbrooke  38th general election           2004-06-28  ...
#
#   Contributor first name Contributor middle initial Contributor City  \
# 0                  DONAT                        NaN            Magog
# 1                   REAL                        NaN       Sherbrooke
# 2                  ANDRE                        NaN            Ascot
# 3               VIOLETTE                        NaN        Shebrooke
# 4                   JEAN                        NaN         Katevale
#
#   Contributor Province Contributor Postal code Contribution Received date  \
# 0                   QC                 J1X 2C3                        NaN
# 1                   QC                 J1L 2B6                        NaN
# 2                   QC                 J1K 3B4                        NaN
# 3                   QC                 J1H 4J9                        NaN
# 4                   QC                 J0B 1W0                        NaN
#
#   Monetary amount Non-Monetary amount Contribution given through  \
# 0           400.0                 0.0                        NaN
# 1           500.0                 0.0                        NaN
# 2           500.0                 0.0                        NaN
# 3          2500.0                 0.0                        NaN
# 4           500.0                 0.0                        NaN
#
#   Leadership contestant
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Political Entity', 'Recipient ID', 'Recipient', 'Recipient last name',
#        'Recipient first name', 'Recipient middle initial',
#        'Political Party of Recipient', 'Electoral District', 'Electoral event',
#        'Fiscal/Election date', 'Form ID', 'Financial Report',
#        'Part Number of Return', 'Financial Report part', 'Contributor type',
#        'Contributor name', 'Contributor last name', 'Contributor first name',
#        'Contributor middle initial', 'Contributor City',
#        'Contributor Province', 'Contributor Postal code',
#        'Contribution Received date', 'Monetary amount', 'Non-Monetary amount',
#        'Contribution given through', 'Leadership contestant'],
#       dtype='object')

# %%
# check for any missing contributions - unlikely to be able to fill in the gaps
df['Monetary amount'].isna().any()
# Out:
# False

# %% [markdown]
# - so no missing contributions, which is excellent in terms of lack of gaps

# %%
# drop unneeded columns
df.drop(columns=['Recipient middle initial', 'Form ID', 'Financial Report',
       'Part Number of Return', 'Financial Report part', 'Contributor type',
       'Contributor name', 'Contributor last name', 'Contributor first name',
       'Contributor middle initial', 'Non-Monetary amount','Contribution given through', 'Leadership contestant'], inplace= True)
df
# Out:
#            Political Entity  Recipient ID                 Recipient  \
# 0               ﻿Candidates          4716      Béchard, Bruno-Marie
# 1                Candidates          4716      Béchard, Bruno-Marie
# 2                Candidates          4716      Béchard, Bruno-Marie
# 3                Candidates          4716      Béchard, Bruno-Marie
# 4                Candidates          4716      Béchard, Bruno-Marie
# ...                     ...           ...                       ...
# 5815958  Registered parties         50874         Free Party Canada
# 5815959  Registered parties         44892         Free Party Canada
# 5815960  Registered parties         44892         Free Party Canada
# 5815961  Registered parties         50876            Maverick Party
# 5815962  Registered parties         50877  Centrist Party of Canada
#
#               Recipient last name Recipient first name  \
# 0                         Béchard          Bruno-Marie
# 1                         Béchard          Bruno-Marie
# 2                         Béchard          Bruno-Marie
# 3                         Béchard          Bruno-Marie
# 4                         Béchard          Bruno-Marie
# ...                           ...                  ...
# 5815958         Free Party Canada                  NaN
# 5815959         Free Party Canada                  NaN
# 5815960         Free Party Canada                  NaN
# 5815961            Maverick Party                  NaN
# 5815962  Centrist Party of Canada                  NaN
#
#         Political Party of Recipient Electoral District  \
# 0            Liberal Party of Canada         Sherbrooke
# 1            Liberal Party of Canada         Sherbrooke
# 2            Liberal Party of Canada         Sherbrooke
# 3            Liberal Party of Canada         Sherbrooke
# 4            Liberal Party of Canada         Sherbrooke
# ...                              ...                ...
# 5815958            Free Party Canada                NaN
# 5815959            Free Party Canada                NaN
# 5815960            Free Party Canada                NaN
# 5815961               Maverick Party                NaN
# 5815962     Centrist Party of Canada                NaN
#
#                Electoral event Fiscal/Election date Contributor City  \
# 0        38th general election           2004-06-28            Magog
# 1        38th general election           2004-06-28       Sherbrooke
# 2        38th general election           2004-06-28            Ascot
# 3        38th general election           2004-06-28        Shebrooke
# 4        38th general election           2004-06-28         Katevale
# ...                        ...                  ...              ...
# 5815958                 Annual           2022-12-31              NaN
# 5815959                 Annual           2021-12-31              NaN
# 5815960                 Annual           2021-12-31              NaN
# 5815961                 Annual           2022-12-31              NaN
# 5815962                 Annual           2022-12-31              NaN
#
#         Contributor Province Contributor Postal code  \
# 0                         QC                 J1X 2C3
# 1                         QC                 J1L 2B6
# 2                         QC                 J1K 3B4
# 3                         QC                 J1H 4J9
# 4                         QC                 J0B 1W0
# ...                      ...                     ...
# 5815958                  NaN                     NaN
# 5815959                  NaN                     NaN
# 5815960                  NaN                     NaN
# 5815961                  NaN                     NaN
# 5815962                  NaN                     NaN
#
#         Contribution Received date  Monetary amount
# 0                              NaN           400.00
# 1                              NaN           500.00
# 2                              NaN           500.00
# 3                              NaN          2500.00
# 4                              NaN           500.00
# ...                            ...              ...
# 5815958                        NaN           380.00
# 5815959                        NaN         27946.30
# 5815960                        NaN           966.50
# 5815961                        NaN         43139.12
# 5815962                        NaN         11270.00
#
# [5815963 rows x 14 columns]

# %% [markdown]
# ### Election events

# %% [markdown]
# Best way forward to join StatsCan sets on electoral outcome would be to identify the elections needed/separate as needed

# %%
df['Electoral event'].unique()
# Out:
# array(['38th general election', '39th general election',
#        'November 27, 2006 By-elections', 'May 27, 2004, By-election',
#        'May 24, 2005 By-election', 'March 17, 2008 By-elections',
#        '40th general election', 'September 17, 2007 By-elections',
#        'September 8, 2008 By-elections', '41st general election',
#        'November 26, 2012 By-elections', 'September 22, 2008 By-election',
#        'November 9, 2009 By-elections', 'November 29, 2010 By-elections',
#        'March 19, 2012 By-election', 'June 30, 2014 By-elections',
#        'November 25, 2013 By-elections', 'May 13, 2013 By-election',
#        'November 17, 2014 By-elections', '42nd general election',
#        'October 24, 2016 By-election', 'April 3, 2017 By-elections',
#        'May 6, 2019 By-election', 'October 23, 2017 By-elections',
#        'February 25, 2019, By-elections',
#        'December 11, 2017, By-elections', 'June 18, 2018, By-election',
#        'December 3, 2018, By-election', 'October 19, 2015 By-elections',
#        '43rd general election', '44th general election',
#        'June 19, 2023, By-elections', 'March 4, 2024, By-election',
#        'October 26, 2020, By-elections', 'December 12, 2022 By-election',
#        'June 24, 2024, By-election', 'July 24, 2023 By-election',
#        'September 16, 2024, By-election', nan, 'Annual', 'Quarterly'],
#       dtype=object)

# %% [markdown]
# Noting above there are A LOT of electoral events - for now we focus on the general elections, by-election results is also available on Elections Canada website

# %%
## 44th election example
df[df['Electoral event'] == '44th general election']
# Out:
#        Political Entity  Recipient ID         Recipient Recipient last name  \
# 118278       Candidates         47414        Ward, Jeff                Ward
# 118279       Candidates         47414        Ward, Jeff                Ward
# 118280       Candidates         47414        Ward, Jeff                Ward
# 118281       Candidates         47414        Ward, Jeff                Ward
# 118282       Candidates         47414        Ward, Jeff                Ward
# ...                 ...           ...               ...                 ...
# 135436       Candidates         48462   Zimmer, Katelyn              Zimmer
# 135437       Candidates         48463       Yeh, Teresa                 Yeh
# 135438       Candidates         48465  Dwyer, Madelaine               Dwyer
# 135439       Candidates         48470      Niles, Tyler               Niles
# 135440       Candidates         48470      Niles, Tyler               Niles
#
#        Recipient first name Political Party of Recipient  \
# 118278                 Jeff         New Democratic Party
# 118279                 Jeff         New Democratic Party
# 118280                 Jeff         New Democratic Party
# 118281                 Jeff         New Democratic Party
# 118282                 Jeff         New Democratic Party
# ...                     ...                          ...
# 135436              Katelyn      Liberal Party of Canada
# 135437               Teresa         New Democratic Party
# 135438            Madelaine         New Democratic Party
# 135439                Tyler     People's Party of Canada
# 135440                Tyler     People's Party of Canada
#
#                                     Electoral District        Electoral event  \
# 118278                                Sydney--Victoria  44th general election
# 118279                                Sydney--Victoria  44th general election
# 118280                                Sydney--Victoria  44th general election
# 118281                                Sydney--Victoria  44th general election
# 118282                                Sydney--Victoria  44th general election
# ...                                                ...                    ...
# 135436                 Moose Jaw--Lake Centre--Lanigan  44th general election
# 135437                                  Brampton North  44th general election
# 135438  Charleswood--St. James--Assiniboia--Headingley  44th general election
# 135439                 Mission--Matsqui--Fraser Canyon  44th general election
# 135440                 Mission--Matsqui--Fraser Canyon  44th general election
#
#        Fiscal/Election date Contributor City Contributor Province  \
# 118278           2021-09-20        Membertou                   NS
# 118279           2021-09-20        Coxhealth                   NS
# 118280           2021-09-20        Membertou                   NS
# 118281           2021-09-20       North York                   ON
# 118282           2021-09-20      Dutch Brook                   NS
# ...                     ...              ...                  ...
# 135436           2021-09-20              NaN                  NaN
# 135437           2021-09-20              NaN                  NaN
# 135438           2021-09-20              NaN                  NaN
# 135439           2021-09-20              NaN                  NaN
# 135440           2021-09-20              NaN                  NaN
#
#        Contributor Postal code Contribution Received date  Monetary amount
# 118278                 B1S 3K8                 2021-09-08           300.00
# 118279                 B1R 1T8                 2021-09-05           500.00
# 118280                 B1S 0K2                 2021-09-15           300.00
# 118281                 M2M 2W2                 2021-09-11           215.00
# 118282                 B1L 1E9                 2021-09-19           400.00
# ...                        ...                        ...              ...
# 135436                     NaN                        NaN            90.00
# 135437                     NaN                        NaN            56.79
# 135438                     NaN                        NaN           250.00
# 135439                     NaN                        NaN           600.00
# 135440                     NaN                        NaN             1.50
#
# [7189 rows x 14 columns]

# %%
# get district codes for each district for better key matching
district_codes_df = pd.read_csv('data/ED-Canada_2021.csv', encoding='latin-1')
district_codes_df
# Out:
#      ED_CODE                                           ED_NAMEE  \
# 0      10001                                             Avalon
# 1      10002                          Bonavista--Burin--Trinity
# 2      10003                 Coast of Bays--Central--Notre Dame
# 3      10004                                           Labrador
# 4      10005                               Long Range Mountains
# ..       ...                                                ...
# 333    59041                                           Victoria
# 334    59042  West Vancouver--Sunshine Coast--Sea to Sky Cou...
# 335    60001                                              Yukon
# 336    61001                              Northwest Territories
# 337    62001                                            Nunavut
#
#                                               ED_NAMEF  POPULATION
# 0                                               Avalon       87191
# 1                            Bonavista--Burin--Trinity       71898
# 2                   Coast of Bays--Central--Notre Dame       74201
# 3                                             Labrador       26655
# 4                                 Long Range Mountains       81716
# ..                                                 ...         ...
# 333                                           Victoria      123482
# 334  West Vancouver--Sunshine Coast--Sea to Sky Cou...      131206
# 335                                              Yukon       40232
# 336                          Territoires du Nord-Ouest       41070
# 337                                            Nunavut       36858
#
# [338 rows x 4 columns]

# %%
# note that 38 - 41 general elections used difference districts as redistricting was done in 2012
# will pull from the 40th general elections list
earlier_district_codes_df = pd.read_csv('data/stats_can_general_elections/40_general_election_11.csv', encoding='latin-1')

# grab the relevant columns
earlier_district_codes_df = earlier_district_codes_df[['Electoral District Name/Nom de circonscription', 'Electoral District Number/Numéro de circonscription']]

# rename a column
earlier_district_codes_df.rename(columns={'Electoral District Number/Numéro de circonscription': 'ED_CODE'}, inplace= True)
earlier_district_codes_df['ED_CODE'] = earlier_district_codes_df['ED_CODE'].astype(int)

# save as a csv for future reference
earlier_district_codes_df.to_csv('data/ed_codes_pre_2012.csv')
earlier_district_codes_df
# Out:
#         Electoral District Name/Nom de circonscription  ED_CODE
# 0                                               Avalon    10001
# 1              Bonavista--Gander--Grand Falls--Windsor    10002
# 2                        Humber--St. Barbe--Baie Verte    10003
# 3                                             Labrador    10004
# 4                          Random--Burin--St. George's    10005
# ..                                                 ...      ...
# 303                                           Victoria    59035
# 304  West Vancouver--Sunshine Coast--Sea to Sky Cou...    59036
# 305                                              Yukon    60001
# 306                                     Western Arctic    61001
# 307                                            Nunavut    62001
#
# [308 rows x 2 columns]

# %%
# create a function to clean the district names
def clean_text(text):
    return re.sub(r'[^\w\s]', ' ', text.lower().strip())


# clean up the district names in the codes dataframes
district_codes_df['cleaned_district_name'] = district_codes_df['ED_NAMEE'].apply(clean_text)
earlier_district_codes_df['cleaned_district_name'] = earlier_district_codes_df['Electoral District Name/Nom de circonscription'].apply(clean_text)

# %%
# process all general elections 
# save individual dataframes just mostly for reference/isolation as needed
earlier_elections_list = ['38th general election', '39th general election', '40th general election',
                          '41st general election']

later_elections_list = ['42nd general election','43rd general election', '44th general election']

# two different loops since we have to use two different sets of electoral codes
for election in earlier_elections_list:
    # pull the dataframe for the specific elections
    election_df = df[df['Electoral event'] == election].copy()

    # clean the district names and merge to add the codes
    election_df['cleaned_district_name'] = election_df['Electoral District'].apply(clean_text)
    merged_df = election_df.merge(earlier_district_codes_df[['cleaned_district_name', 'ED_CODE']].copy(), on= 'cleaned_district_name', how='left')
    
    # drop the temporary name col (?) might keep for elections outcome merging

    # save to csv
    merged_df.to_csv(f'data/contributions/general_elections/{election}.csv')


for election in later_elections_list:
    # pull the dataframe for the specific elections
    election_df = df[df['Electoral event'] == election].copy()

    # clean the district names and merge to add the codes
    election_df['cleaned_district_name'] = election_df['Electoral District'].apply(clean_text)
    merged_df = election_df.merge(district_codes_df[['cleaned_district_name', 'ED_CODE']].copy(), on= 'cleaned_district_name', how='left')
    
    # drop the temporary name col (?) might keep for elections outcome merging

    # save to csv
    merged_df.to_csv(f'data/contributions/general_elections/{election}.csv')

# %% [markdown]
# ### StatsCan/Election Canada Data

# %% [markdown]
# ### Initial preprocessing and function set up

# %%
stats_df = pd.read_csv('data/stats_can_general_elections/44_general_election_12.csv')
stats_df
# Out:
#                                                Province  \
# 0     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 1     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 2     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 3     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 4     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# ...                                                 ...
# 2005    Northwest Territories/Territoires du Nord-Ouest
# 2006    Northwest Territories/Territoires du Nord-Ouest
# 2007                                            Nunavut
# 2008                                            Nunavut
# 2009                                            Nunavut
#
#        Electoral District Name/Nom de circonscription  \
# 0                                              Avalon
# 1                                              Avalon
# 2                                              Avalon
# 3                                              Avalon
# 4                           Bonavista--Burin--Trinity
# ...                                               ...
# 2005  Northwest Territories/Territoires du Nord-Ouest
# 2006  Northwest Territories/Territoires du Nord-Ouest
# 2007                                          Nunavut
# 2008                                          Nunavut
# 2009                                          Nunavut
#
#       Electoral District Number/Numéro de circonscription  \
# 0                                                 10001
# 1                                                 10001
# 2                                                 10001
# 3                                                 10001
# 4                                                 10002
# ...                                                 ...
# 2005                                              61001
# 2006                                              61001
# 2007                                              62001
# 2008                                              62001
# 2009                                              62001
#
#                                      Candidate/Candidat  \
# 0                       Ken McDonald ** Liberal/Libéral
# 1             Matthew Chapman Conservative/Conservateur
# 2     Carolyn Davis NDP-New Democratic Party/NPD-Nou...
# 3     Lainie Stewart People's Party - PPC/Parti popu...
# 4                    Churence Rogers ** Liberal/Libéral
# ...                                                 ...
# 2005        Jane Groenewegen Independent/Indépendant(e)
# 2006               Roland Laufer Green Party/Parti Vert
# 2007  Lori Idlout NDP-New Democratic Party/NPD-Nouve...
# 2008                       Pat Angnakak Liberal/Libéral
# 2009          Laura Mackenzie Conservative/Conservateur
#
#        Candidate Residence/Résidence du candidat  \
# 0           Conception Bay South, N.L./ T.-N.-L.
# 1                       Paradise, N.L./ T.-N.-L.
# 2     Portugal Cove-St. Philip's, N.L./ T.-N.-L.
# 3                    Mount Pearl, N.L./ T.-N.-L.
# 4                    Centreville, N.L./ T.-N.-L.
# ...                                          ...
# 2005                  Hay River, N.W.T./ T.N.-O.
# 2006                Yellowknife, N.W.T./ T.N.-O.
# 2007                           Iqaluit, Nun./ Nt
# 2008                           Iqaluit, Nun./ Nt
# 2009                           Iqaluit, Nun./ Nt
#
#             Candidate Occupation/Profession du candidat  \
# 0                         Parliamentarian/Parlementaire
# 1                                    Teacher/Enseignant
# 2     Claims Representative/Représentante en réclama...
# 3              Business Owner/Propriétaire d'entreprise
# 4                         Parliamentarian/Parlementaire
# ...                                                 ...
# 2005                    Business Woman/Femme d'affaires
# 2006                 Store Manager/Directeur de magasin
# 2007                                     Lawyer/Avocate
# 2008                      Parliamentarian/Parlementaire
# 2009  Civil Servant and Business Owner/Fonctionnaire...
#
#       Votes Obtained/Votes obtenus  \
# 0                            18608
# 1                            12738
# 2                             5151
# 3                              647
# 4                            13972
# ...                            ...
# 2005                          1791
# 2006                           328
# 2007                          3427
# 2008                          2578
# 2009                          1184
#
#       Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0                                                  50.1
# 1                                                  34.3
# 2                                                  13.9
# 3                                                   1.7
# 4                                                  46.6
# ...                                                 ...
# 2005                                               12.7
# 2006                                                2.3
# 2007                                               47.7
# 2008                                               35.9
# 2009                                               16.5
#
#       Majority/Majorité  Majority Percentage/Pourcentage de majorité
# 0                5870.0                                         15.8
# 1                   NaN                                          NaN
# 2                   NaN                                          NaN
# 3                   NaN                                          NaN
# 4                1694.0                                          5.6
# ...                 ...                                          ...
# 2005                NaN                                          NaN
# 2006                NaN                                          NaN
# 2007              849.0                                         11.8
# 2008                NaN                                          NaN
# 2009                NaN                                          NaN
#
# [2010 rows x 10 columns]

# %%
# function to set up add and drop columns 
def add_drop_cols(df):
    df['won_election'] = df['Majority/Majorité'].notna()
    df = df.drop(columns=['Province', 'Candidate Residence/Résidence du candidat','Candidate Occupation/Profession du candidat',
               'Votes Obtained/Votes obtenus', 'Majority/Majorité', 'Majority Percentage/Pourcentage de majorité'])

    return df

add_drop_cols(stats_df)
# Out:
#        Electoral District Name/Nom de circonscription  \
# 0                                              Avalon
# 1                                              Avalon
# 2                                              Avalon
# 3                                              Avalon
# 4                           Bonavista--Burin--Trinity
# ...                                               ...
# 2005  Northwest Territories/Territoires du Nord-Ouest
# 2006  Northwest Territories/Territoires du Nord-Ouest
# 2007                                          Nunavut
# 2008                                          Nunavut
# 2009                                          Nunavut
#
#       Electoral District Number/Numéro de circonscription  \
# 0                                                 10001
# 1                                                 10001
# 2                                                 10001
# 3                                                 10001
# 4                                                 10002
# ...                                                 ...
# 2005                                              61001
# 2006                                              61001
# 2007                                              62001
# 2008                                              62001
# 2009                                              62001
#
#                                      Candidate/Candidat  \
# 0                       Ken McDonald ** Liberal/Libéral
# 1             Matthew Chapman Conservative/Conservateur
# 2     Carolyn Davis NDP-New Democratic Party/NPD-Nou...
# 3     Lainie Stewart People's Party - PPC/Parti popu...
# 4                    Churence Rogers ** Liberal/Libéral
# ...                                                 ...
# 2005        Jane Groenewegen Independent/Indépendant(e)
# 2006               Roland Laufer Green Party/Parti Vert
# 2007  Lori Idlout NDP-New Democratic Party/NPD-Nouve...
# 2008                       Pat Angnakak Liberal/Libéral
# 2009          Laura Mackenzie Conservative/Conservateur
#
#       Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0                                                  50.1
# 1                                                  34.3
# 2                                                  13.9
# 3                                                   1.7
# 4                                                  46.6
# ...                                                 ...
# 2005                                               12.7
# 2006                                                2.3
# 2007                                               47.7
# 2008                                               35.9
# 2009                                               16.5
#
#       won_election
# 0             True
# 1            False
# 2            False
# 3            False
# 4             True
# ...            ...
# 2005         False
# 2006         False
# 2007          True
# 2008         False
# 2009         False
#
# [2010 rows x 5 columns]

# %%
# set up dictionary of party names and variations to check the party
parties_dict = {
    "animal protection party of canada": [
        "animal protection party of canada",
        "animal protection party"
    ],
    "bloc québécois": [
        "bloc québécois",
        "bloc quebecois",
        "bloc",
        "bq"
    ],
    "canadian future party": [
        "canadian future party"
    ],
    "centrist party of canada": [
        "centrist party of canada",
        "centrist party"
    ],
    "christian heritage party of canada": [
        "christian heritage party of canada",
        "christian heritage party",
        "chp"
    ],
    "communist party of canada": [
        "communist party of canada",
        "communist party"
    ],
    "conservative": [
        "conservative",
        "conservative party",
        "conservative party of canada",
        "cpc"
    ],
    "green": [
        "green",
        "green party",
        "green party of canada",
        "green party/parti vert",
        "parti vert"
    ],
    "liberal": [
        "liberal",
        "liberal party",
        "liberal party of canada",
        "lpc"
    ],
    "libertarian party of canada": [
        "libertarian party of canada",
        "libertarian party"
    ],
    "marijuana party": [
        "marijuana party"
    ],
    "marxist-leninist party of canada": [
        "marxist-leninist party of canada",
        "marxist leninist party",
        "marxist leninist"
    ],
    "ndp": [
        "ndp",
        "new democratic party",
        "ndp - new democratic party",
        "ndp-new democratic party",
        "ndp/new democratic party"
    ],
    "parti rhinocéros party": [
        "parti rhinocéros party",
        "rhinoceros party",
        "parti rhinoceros"
    ],
    "united party of canada (up)": [
        "united party of canada",
        "up",
        "united party of canada (up)"
    ],
    "people's party of canada": [
        "people's party of canada",
        "people's party",
        "people's party - ppc",
        "peoples party",
        "peoples party of canada",
        "peoples party ppc"
    ],
    "independent": [
        "independent",
        "indépendant",
        "indépendante",
        "independent/indépendant",
        "independent/indépendante",
        "indépendant(e)"
    ],
    "other parties":[
        "pour l'indépendance du québec",
        "vcp",
        "cac",
        "vcp/cac",
        "canada's fourth front",
        "qfc",
        "qfc/canada's fourth front",
        "no affiliation",
        "aucune affiliation",
        "aucune appartenance",
        "national citizens alliance",
        "nca",
        "nationalist",
        "nationaliste",
        "parti patriote",
        "canadian action",
        "action canadienne",
        "ml/ml",
        "stop climate change",
        "democratic advancement",
        "forces et démocratie",
        "atn",
        "pirate",
        "pirate party",
        "cap",
        "pac",
        "pact",
        "the bridge",
        "fpnp",
        "wbp",
        "chp canada",
        "ppp",
        "neorhino.ca"
    ]
}

# a quick basic cleaning text function (similar to the one used in )
def clean_text_parties(text):
    return re.sub(r'[^\w\s]', '', text.lower().strip())

# flatting the dict into a list to use:
parties_list = []
for party, alternatives in parties_dict.items():
    parties_list.extend(alternatives)

# quick display to look at list   
parties_list
# Out:
# ['animal protection party of canada',
#  'animal protection party',
#  'bloc québécois',
#  'bloc quebecois',
#  'bloc',
#  'bq',
#  'canadian future party',
#  'centrist party of canada',
#  'centrist party',
#  'christian heritage party of canada',
#  'christian heritage party',
#  'chp',
#  'communist party of canada',
#  'communist party',
#  'conservative',
#  'conservative party',
#  'conservative party of canada',
#  'cpc',
#  'green',
#  'green party',
#  'green party of canada',
#  'green party/parti vert',
#  'parti vert',
#  'liberal',
#  'liberal party',
#  'liberal party of canada',
#  'lpc',
#  'libertarian party of canada',
#  'libertarian party',
#  'marijuana party',
#  'marxist-leninist party of canada',
#  'marxist leninist party',
#  'marxist leninist',
#  'ndp',
#  'new democratic party',
#  'ndp - new democratic party',
#  'ndp-new democratic party',
#  'ndp/new democratic party',
#  'parti rhinocéros party',
#  'rhinoceros party',
#  'parti rhinoceros',
#  'united party of canada',
#  'up',
#  'united party of canada (up)',
#  "people's party of canada",
#  "people's party",
#  "people's party - ppc",
#  'peoples party',
#  'peoples party of canada',
#  'peoples party ppc',
#  'independent',
#  'indépendant',
#  'indépendante',
#  'independent/indépendant',
#  'independent/indépendante',
#  'indépendant(e)',
#  "pour l'indépendance du québec",
#  'vcp',
#  'cac',
#  'vcp/cac',
#  "canada's fourth front",
#  'qfc',
#  "qfc/canada's fourth front",
#  'no affiliation',
#  'aucune affiliation',
#  'aucune appartenance',
#  'national citizens alliance',
#  'nca',
#  'nationalist',
#  'nationaliste',
#  'parti patriote',
#  'canadian action',
#  'action canadienne',
#  'ml/ml',
#  'stop climate change',
#  'democratic advancement',
#  'forces et démocratie',
#  'atn',
#  'pirate',
#  'pirate party',
#  'cap',
#  'pac',
#  'pact',
#  'the bridge',
#  'fpnp',
#  'wbp',
#  'chp canada',
#  'ppp',
#  'neorhino.ca']

# %%
# function to separate out the party, and the name to match closer to the contributions dataframe

def get_candidate_names(text, parties_list):
    # string check, return None for manual check
    if not isinstance(text, str):
        return None
    
    # remove the stars with regex
    text = re.sub(r'\*\*', '', text).strip()


    # split out the party part
    before_slash, french_party = text.rsplit('/', 1)
    
    # grab the name & english party
    words = before_slash.strip().split()
    best_score = 0
    best_index = len(words)

    for i in range(1, len(words)):
        potential_party = ' '.join(words[i:])
        potential_party = clean_text_parties(potential_party)
        match, score, _ = process.extractOne(potential_party, parties_list)
        if score > best_score:
            best_score = score
            best_index = i

    if best_score > 85:
        return ' '.join(words[:best_index])

    # return the original text if it doesn't work, will flag all "None" for manual check
    return None

# %%
# apply to dataframes
stats_df['Candidate Name'] = stats_df['Candidate/Candidat'].apply(lambda x: get_candidate_names(x, parties_list))
stats_df
# Out:
#                                                Province  \
# 0     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 1     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 2     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 3     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 4     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# ...                                                 ...
# 2005    Northwest Territories/Territoires du Nord-Ouest
# 2006    Northwest Territories/Territoires du Nord-Ouest
# 2007                                            Nunavut
# 2008                                            Nunavut
# 2009                                            Nunavut
#
#        Electoral District Name/Nom de circonscription  \
# 0                                              Avalon
# 1                                              Avalon
# 2                                              Avalon
# 3                                              Avalon
# 4                           Bonavista--Burin--Trinity
# ...                                               ...
# 2005  Northwest Territories/Territoires du Nord-Ouest
# 2006  Northwest Territories/Territoires du Nord-Ouest
# 2007                                          Nunavut
# 2008                                          Nunavut
# 2009                                          Nunavut
#
#       Electoral District Number/Numéro de circonscription  \
# 0                                                 10001
# 1                                                 10001
# 2                                                 10001
# 3                                                 10001
# 4                                                 10002
# ...                                                 ...
# 2005                                              61001
# 2006                                              61001
# 2007                                              62001
# 2008                                              62001
# 2009                                              62001
#
#                                      Candidate/Candidat  \
# 0                       Ken McDonald ** Liberal/Libéral
# 1             Matthew Chapman Conservative/Conservateur
# 2     Carolyn Davis NDP-New Democratic Party/NPD-Nou...
# 3     Lainie Stewart People's Party - PPC/Parti popu...
# 4                    Churence Rogers ** Liberal/Libéral
# ...                                                 ...
# 2005        Jane Groenewegen Independent/Indépendant(e)
# 2006               Roland Laufer Green Party/Parti Vert
# 2007  Lori Idlout NDP-New Democratic Party/NPD-Nouve...
# 2008                       Pat Angnakak Liberal/Libéral
# 2009          Laura Mackenzie Conservative/Conservateur
#
#        Candidate Residence/Résidence du candidat  \
# 0           Conception Bay South, N.L./ T.-N.-L.
# 1                       Paradise, N.L./ T.-N.-L.
# 2     Portugal Cove-St. Philip's, N.L./ T.-N.-L.
# 3                    Mount Pearl, N.L./ T.-N.-L.
# 4                    Centreville, N.L./ T.-N.-L.
# ...                                          ...
# 2005                  Hay River, N.W.T./ T.N.-O.
# 2006                Yellowknife, N.W.T./ T.N.-O.
# 2007                           Iqaluit, Nun./ Nt
# 2008                           Iqaluit, Nun./ Nt
# 2009                           Iqaluit, Nun./ Nt
#
#             Candidate Occupation/Profession du candidat  \
# 0                         Parliamentarian/Parlementaire
# 1                                    Teacher/Enseignant
# 2     Claims Representative/Représentante en réclama...
# 3              Business Owner/Propriétaire d'entreprise
# 4                         Parliamentarian/Parlementaire
# ...                                                 ...
# 2005                    Business Woman/Femme d'affaires
# 2006                 Store Manager/Directeur de magasin
# 2007                                     Lawyer/Avocate
# 2008                      Parliamentarian/Parlementaire
# 2009  Civil Servant and Business Owner/Fonctionnaire...
#
#       Votes Obtained/Votes obtenus  \
# 0                            18608
# 1                            12738
# 2                             5151
# 3                              647
# 4                            13972
# ...                            ...
# 2005                          1791
# 2006                           328
# 2007                          3427
# 2008                          2578
# 2009                          1184
#
#       Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0                                                  50.1
# 1                                                  34.3
# 2                                                  13.9
# 3                                                   1.7
# 4                                                  46.6
# ...                                                 ...
# 2005                                               12.7
# 2006                                                2.3
# 2007                                               47.7
# 2008                                               35.9
# 2009                                               16.5
#
#       Majority/Majorité  Majority Percentage/Pourcentage de majorité  \
# 0                5870.0                                         15.8
# 1                   NaN                                          NaN
# 2                   NaN                                          NaN
# 3                   NaN                                          NaN
# 4                1694.0                                          5.6
# ...                 ...                                          ...
# 2005                NaN                                          NaN
# 2006                NaN                                          NaN
# 2007              849.0                                         11.8
# 2008                NaN                                          NaN
# 2009                NaN                                          NaN
#
#       won_election    Candidate Name
# 0             True      Ken McDonald
# 1            False   Matthew Chapman
# 2            False     Carolyn Davis
# 3            False    Lainie Stewart
# 4             True   Churence Rogers
# ...            ...               ...
# 2005         False  Jane Groenewegen
# 2006         False     Roland Laufer
# 2007          True       Lori Idlout
# 2008         False      Pat Angnakak
# 2009         False   Laura Mackenzie
#
# [2010 rows x 12 columns]

# %%
# check for any missing candidate names
stats_df[stats_df['Candidate Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Province, Electoral District Name/Nom de circonscription, Electoral District Number/Numéro de circonscription, Candidate/Candidat, Candidate Residence/Résidence du candidat, Candidate Occupation/Profession du candidat, Votes Obtained/Votes obtenus, Percentage of Votes Obtained /Pourcentage des votes obtenus, Majority/Majorité, Majority Percentage/Pourcentage de majorité, won_election, Candidate Name]
# Index: []

# %%
def split_name(text):
    # return Nones if somehow we missed something, to flag for a manual check
    if text is None:
        return pd.Series([None, None])
    
    names = text.split()
    # if somehow we only got the first name/one word, might require in manual check, set last name to none
    if len(names) == 1:
        return pd.Series([names[0], None])
    else:
        return pd.Series([names[0], names[-1]])

stats_df[['First Name', 'Last Name']] = stats_df['Candidate Name'].apply(split_name)
stats_df
# Out:
#                                                Province  \
# 0     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 1     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 2     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 3     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 4     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# ...                                                 ...
# 2005    Northwest Territories/Territoires du Nord-Ouest
# 2006    Northwest Territories/Territoires du Nord-Ouest
# 2007                                            Nunavut
# 2008                                            Nunavut
# 2009                                            Nunavut
#
#        Electoral District Name/Nom de circonscription  \
# 0                                              Avalon
# 1                                              Avalon
# 2                                              Avalon
# 3                                              Avalon
# 4                           Bonavista--Burin--Trinity
# ...                                               ...
# 2005  Northwest Territories/Territoires du Nord-Ouest
# 2006  Northwest Territories/Territoires du Nord-Ouest
# 2007                                          Nunavut
# 2008                                          Nunavut
# 2009                                          Nunavut
#
#       Electoral District Number/Numéro de circonscription  \
# 0                                                 10001
# 1                                                 10001
# 2                                                 10001
# 3                                                 10001
# 4                                                 10002
# ...                                                 ...
# 2005                                              61001
# 2006                                              61001
# 2007                                              62001
# 2008                                              62001
# 2009                                              62001
#
#                                      Candidate/Candidat  \
# 0                       Ken McDonald ** Liberal/Libéral
# 1             Matthew Chapman Conservative/Conservateur
# 2     Carolyn Davis NDP-New Democratic Party/NPD-Nou...
# 3     Lainie Stewart People's Party - PPC/Parti popu...
# 4                    Churence Rogers ** Liberal/Libéral
# ...                                                 ...
# 2005        Jane Groenewegen Independent/Indépendant(e)
# 2006               Roland Laufer Green Party/Parti Vert
# 2007  Lori Idlout NDP-New Democratic Party/NPD-Nouve...
# 2008                       Pat Angnakak Liberal/Libéral
# 2009          Laura Mackenzie Conservative/Conservateur
#
#        Candidate Residence/Résidence du candidat  \
# 0           Conception Bay South, N.L./ T.-N.-L.
# 1                       Paradise, N.L./ T.-N.-L.
# 2     Portugal Cove-St. Philip's, N.L./ T.-N.-L.
# 3                    Mount Pearl, N.L./ T.-N.-L.
# 4                    Centreville, N.L./ T.-N.-L.
# ...                                          ...
# 2005                  Hay River, N.W.T./ T.N.-O.
# 2006                Yellowknife, N.W.T./ T.N.-O.
# 2007                           Iqaluit, Nun./ Nt
# 2008                           Iqaluit, Nun./ Nt
# 2009                           Iqaluit, Nun./ Nt
#
#             Candidate Occupation/Profession du candidat  \
# 0                         Parliamentarian/Parlementaire
# 1                                    Teacher/Enseignant
# 2     Claims Representative/Représentante en réclama...
# 3              Business Owner/Propriétaire d'entreprise
# 4                         Parliamentarian/Parlementaire
# ...                                                 ...
# 2005                    Business Woman/Femme d'affaires
# 2006                 Store Manager/Directeur de magasin
# 2007                                     Lawyer/Avocate
# 2008                      Parliamentarian/Parlementaire
# 2009  Civil Servant and Business Owner/Fonctionnaire...
#
#       Votes Obtained/Votes obtenus  \
# 0                            18608
# 1                            12738
# 2                             5151
# 3                              647
# 4                            13972
# ...                            ...
# 2005                          1791
# 2006                           328
# 2007                          3427
# 2008                          2578
# 2009                          1184
#
#       Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0                                                  50.1
# 1                                                  34.3
# 2                                                  13.9
# 3                                                   1.7
# 4                                                  46.6
# ...                                                 ...
# 2005                                               12.7
# 2006                                                2.3
# 2007                                               47.7
# 2008                                               35.9
# 2009                                               16.5
#
#       Majority/Majorité  Majority Percentage/Pourcentage de majorité  \
# 0                5870.0                                         15.8
# 1                   NaN                                          NaN
# 2                   NaN                                          NaN
# 3                   NaN                                          NaN
# 4                1694.0                                          5.6
# ...                 ...                                          ...
# 2005                NaN                                          NaN
# 2006                NaN                                          NaN
# 2007              849.0                                         11.8
# 2008                NaN                                          NaN
# 2009                NaN                                          NaN
#
#       won_election    Candidate Name First Name    Last Name
# 0             True      Ken McDonald        Ken     McDonald
# 1            False   Matthew Chapman    Matthew      Chapman
# 2            False     Carolyn Davis    Carolyn        Davis
# 3            False    Lainie Stewart     Lainie      Stewart
# 4             True   Churence Rogers   Churence       Rogers
# ...            ...               ...        ...          ...
# 2005         False  Jane Groenewegen       Jane  Groenewegen
# 2006         False     Roland Laufer     Roland       Laufer
# 2007          True       Lori Idlout       Lori       Idlout
# 2008         False      Pat Angnakak        Pat     Angnakak
# 2009         False   Laura Mackenzie      Laura    Mackenzie
#
# [2010 rows x 14 columns]

# %%
# check for missing last names to see if there are any splitting issues
stats_df[stats_df['Last Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Province, Electoral District Name/Nom de circonscription, Electoral District Number/Numéro de circonscription, Candidate/Candidat, Candidate Residence/Résidence du candidat, Candidate Occupation/Profession du candidat, Votes Obtained/Votes obtenus, Percentage of Votes Obtained /Pourcentage des votes obtenus, Majority/Majorité, Majority Percentage/Pourcentage de majorité, won_election, Candidate Name, First Name, Last Name]
# Index: []

# %%
# function to do the
def merge_elections(contribution_df, outcome_df):
    merged_df = contribution_df.merge(outcome_df, 
                                   on= ['ED_CODE','Recipient first name', 'Recipient last name'], how= 'inner')
    merged_df.drop(columns= ['Unnamed: 0','Electoral District/Circonscription', 'Electoral District Name/Nom de circonscription',
                             'Candidate/Candidat', 'cleaned_district_name_y','Candidate Name'], 
                             inplace = True, errors='ignore')
    return merged_df

# %% [markdown]
# ### Process all elections

# %% [markdown]
# #### 38th Election

# %%
# grab the relevant data frames
election_contributions_38_df = pd.read_csv('data/contributions/general_elections/38th general election.csv')
election_outcomes_38_df = pd.read_csv('data/stats_can_general_elections/38_general_election_12.csv', encoding = 'latin-1')

# %%
# 38th election needs an additional merge to pick up the ED CODES
election_outcomes_38_df['cleaned_district_name'] = election_outcomes_38_df['Electoral District/Circonscription'].apply(clean_text)
election_outcomes_38_df = election_outcomes_38_df.merge(earlier_district_codes_df[['cleaned_district_name', 'ED_CODE']].copy(), on= 'cleaned_district_name', how='left')

election_outcomes_38_df
# Out:
#                                                Province  \
# 0     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 1     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 2     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 3     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 4     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# ...                                                 ...
# 1680                                            Nunavut
# 1681                                            Nunavut
# 1682                                            Nunavut
# 1683                                            Nunavut
# 1684                                            Nunavut
#
#      Electoral District/Circonscription  \
# 0                                Avalon
# 1                                Avalon
# 2                                Avalon
# 3                                Avalon
# 4                   Bonavista--Exploits
# ...                                 ...
# 1680                            Nunavut
# 1681                            Nunavut
# 1682                            Nunavut
# 1683                            Nunavut
# 1684                            Nunavut
#
#                                Candidate/Candidat  \
# 0               R. John Efford ** Liberal/Libéral
# 1           Rick Dalton Conservative/conservateur
# 2                     Michael Kehoe N.D.P./N.P.D.
# 3          Don C. Ferguson Green Party/Parti Vert
# 4                     Scott Simms Liberal/Libéral
# ...                                           ...
# 1680     Nancy Karetak-Lindell ** Liberal/Libéral
# 1681     Manitok Thompson Independent/Indépendant
# 1682                   Bill Riddell N.D.P./N.P.D.
# 1683  Duncan Cunningham Conservative/conservateur
# 1684           Nedd Kenney Green Party/Parti Vert
#
#      Candidate Residence/Résidence du candidat  \
# 0                      Bareneed, N.L./T.-N.-L.
# 1                  Harbour Main, N.L./T.-N.-L.
# 2                      Paradise, N.L./T.-N.-L.
# 3                        Lethbridge, Alta/Alb.
# 4                Bishop's Falls, N.L./T.-N.-L.
# ...                                        ...
# 1680                              Arviat, Nnvt
# 1681                        Rankin Inlet, Nnvt
# 1682                             Iqaluit, Nnvt
# 1683                          Pond Inlet, Nnvt
# 1684                       Cambridge Bay, Nnvt
#
#             Candidate Occupation/Profession du candidat  \
# 0                         Parliamentarian/Parlementaire
# 1             Business Manager/Directeur des opérations
# 2     Customer Service Representative/Représentant a...
# 3             Professor (Retired)/Professeur (retraité)
# 4                            Broadcaster/Radiodiffuseur
# ...                                                 ...
# 1680                      Parliamentarian/Parlementaire
# 1681                                Teacher/Enseignante
# 1682                                 Mediator/Médiateur
# 1683                               Manager/Gestionnaire
# 1684             Music Instructor/Professeur de musique
#
#       Votes Obtained/Votes obtenus  \
# 0                            18335
# 1                             9211
# 2                             3450
# 3                              430
# 4                            15970
# ...                            ...
# 1680                          3818
# 1681                          1172
# 1682                          1129
# 1683                          1075
# 1684                           248
#
#       Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0                                                 58.34
# 1                                                 29.31
# 2                                                 10.98
# 3                                                  1.37
# 4                                                 48.20
# ...                                                 ...
# 1680                                              51.30
# 1681                                              15.75
# 1682                                              15.17
# 1683                                              14.45
# 1684                                               3.33
#
#       Majority/Majorité  Majority Percentage/Pourcentage de majorité  \
# 0                9124.0                                         29.0
# 1                   NaN                                          NaN
# 2                   NaN                                          NaN
# 3                   NaN                                          NaN
# 4                2184.0                                          6.6
# ...                 ...                                          ...
# 1680             2646.0                                         35.6
# 1681                NaN                                          NaN
# 1682                NaN                                          NaN
# 1683                NaN                                          NaN
# 1684                NaN                                          NaN
#
#      cleaned_district_name  ED_CODE
# 0                   avalon  10001.0
# 1                   avalon  10001.0
# 2                   avalon  10001.0
# 3                   avalon  10001.0
# 4      bonavista  exploits      NaN
# ...                    ...      ...
# 1680               nunavut  62001.0
# 1681               nunavut  62001.0
# 1682               nunavut  62001.0
# 1683               nunavut  62001.0
# 1684               nunavut  62001.0
#
# [1685 rows x 11 columns]

# %%
# catch any missing district codes
election_outcomes_38_df[election_outcomes_38_df['ED_CODE'].isna()]
# Out:
#                                                Province  \
# 4     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 5     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 6     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 7     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 8     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# ...                                                 ...
# 1665              British Columbia/Colombie-Britannique
# 1666              British Columbia/Colombie-Britannique
# 1667              British Columbia/Colombie-Britannique
# 1668              British Columbia/Colombie-Britannique
# 1669              British Columbia/Colombie-Britannique
#
#      Electoral District/Circonscription  \
# 4                   Bonavista--Exploits
# 5                   Bonavista--Exploits
# 6                   Bonavista--Exploits
# 7                   Bonavista--Exploits
# 8                   Bonavista--Exploits
# ...                                 ...
# 1665     West Vancouver--Sunshine Coast
# 1666     West Vancouver--Sunshine Coast
# 1667     West Vancouver--Sunshine Coast
# 1668     West Vancouver--Sunshine Coast
# 1669     West Vancouver--Sunshine Coast
#
#                                      Candidate/Candidat  \
# 4                           Scott Simms Liberal/Libéral
# 5               Rex Barnes ** Conservative/conservateur
# 6                    Samuel Robert McLean N.D.P./N.P.D.
# 7                Ed Sailor White Green Party/Parti Vert
# 8                   John Lannon Independent/Indépendant
# ...                                                 ...
# 1665                       Blair Wilson Liberal/Libéral
# 1666                      Nicholas Simons N.D.P./N.P.D.
# 1667            Andrea Goldsmith Green Party/Parti Vert
# 1668     Marc Bombois Canadian Action/Action canadienne
# 1669  Anne Jamieson Marxist-Leninist/Marxiste-Léniniste
#
#      Candidate Residence/Résidence du candidat  \
# 4                Bishop's Falls, N.L./T.-N.-L.
# 5           Grand Falls-Windsor, N.L./T.-N.-L.
# 6                        Gander, N.L./T.-N.-L.
# 7                    St. John's, N.L./T.-N.-L.
# 8                        Gander, N.L./T.-N.-L.
# ...                                        ...
# 1665                  West Vancouver, BC/C.-B.
# 1666                         Gibsons, BC/C.-B.
# 1667                         Gibsons, BC/C.-B.
# 1668                        Squamish, BC/C.-B.
# 1669                    Bowen Island, BC/C.-B.
#
#        Candidate Occupation/Profession du candidat  \
# 4                       Broadcaster/Radiodiffuseur
# 5                    Parliamentarian/Parlementaire
# 6                               Teacher/Enseignant
# 7     Former WWF Wrestler/Ancien lutteur de la WWF
# 8               Self-employed/Travailleur autonome
# ...                                            ...
# 1665          Chartered Accountant/Comptable agréé
# 1666                         Consultant/Consultant
# 1667        Town Councillor/Conseillère municipale
# 1668       General Contractor/Entrepreneur général
# 1669         Registered Nurse/Infirmière autorisée
#
#       Votes Obtained/Votes obtenus  \
# 4                            15970
# 5                            13786
# 6                             2667
# 7                              367
# 8                              344
# ...                            ...
# 1665                         19685
# 1666                         13156
# 1667                          5887
# 1668                           321
# 1669                           123
#
#       Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 4                                                 48.20
# 5                                                 41.61
# 6                                                  8.05
# 7                                                  1.11
# 8                                                  1.04
# ...                                                 ...
# 1665                                              32.51
# 1666                                              21.73
# 1667                                               9.72
# 1668                                               0.53
# 1669                                               0.20
#
#       Majority/Majorité  Majority Percentage/Pourcentage de majorité  \
# 4                2184.0                                          6.6
# 5                   NaN                                          NaN
# 6                   NaN                                          NaN
# 7                   NaN                                          NaN
# 8                   NaN                                          NaN
# ...                 ...                                          ...
# 1665                NaN                                          NaN
# 1666                NaN                                          NaN
# 1667                NaN                                          NaN
# 1668                NaN                                          NaN
# 1669                NaN                                          NaN
#
#                cleaned_district_name  ED_CODE
# 4                bonavista  exploits      NaN
# 5                bonavista  exploits      NaN
# 6                bonavista  exploits      NaN
# 7                bonavista  exploits      NaN
# 8                bonavista  exploits      NaN
# ...                              ...      ...
# 1665  west vancouver  sunshine coast      NaN
# 1666  west vancouver  sunshine coast      NaN
# 1667  west vancouver  sunshine coast      NaN
# 1668  west vancouver  sunshine coast      NaN
# 1669  west vancouver  sunshine coast      NaN
#
# [194 rows x 11 columns]

# %%
# filling the missing districts codes
missing_codes_map = {
    'Bonavista--Exploits': 10002,
    "St. John's North/St. John's-Nord": 10006,
    "St. John's South/St. John's-Sud": 10007,
    "North Nova/Nova-Nord": 12007,  # was renamed post-election to Cumberland--Colchester--Musquodoboit Valley
    "North Okanagan--Shuswap/Okanagan-Nord--Shuswap": 59018,
    "West Vancouver--Sunshine Coast": 59036,
    "Southern Interior": 59026,
    "Fundy": 13004,  # Fundy Royal
    "St. Croix--Belleisle": 13008,  # Renamed to New Brunswick Southwest
    "Argenteuil--Mirabel": 24004,  # Argenteuil--Papineau--Mirabel
    "Beauport": 24007,  # Beauport--Limoilou
    "Charlesbourg": 24013,  # Charlesbourg--Haute-Saint-Charles
    "Charlevoix--Montmorency": 24014,  # Montmorency--Charlevoix--Haute-Côte-Nord
    "Laurier": 24031,  # Laurier--Sainte-Marie
    "Longueuil": 24035,  # Longueuil--Pierre-Boucher
    "Matapédia--Matane": 24041,  # Haute-Gaspésie--La Mitis--Matane--Matapédia
    "Nunavik--Eeyou": 24046,  # Abitibi--Baie-James--Nunavik--Eeyou
    "Portneuf": 24051,  # Portneuf--Jacques-Cartier
    "Richelieu": 24054,  # Bas-Richelieu--Nicolet--Bécancour
    "Rimouski--Témiscouata": 24056,  # Rimouski-Neigette--Témiscouata--Les Basques
    "Rivière-du-Loup--Montmagny": 24058,  # Montmagny--L'Islet--Kamouraska--Rivière-du-Loup
    "Roberval": 24060,  # Roberval--Lac-Saint-Jean
    "Carleton--Lanark": 35012,  # Carleton--Mississippi Mills
    "Clarington--Scugog--Uxbridge": 35014,  # Renamed to Durham
    "Grey--Bruce--Owen Sound": 35026,  # Bruce--Grey--Owen Sound
    "Middlesex--Kent--Lambton": 35046,  # Lambton--Kent--Middlesex
    "Charleswood--St. James": 46002,  # Charleswood--St. James--Assiniboia
    "Dauphin--Swan River": 46004,  # Dauphin--Swan River--Marquette
    "Churchill River/Rivière Churchill": 47003,  # Desnethé--Missinippi--Churchill River
    "Athabasca": 48001,  # Fort McMurray--Athabasca
    "Calgary North Centre/Calgary-Centre-Nord": 48003,  # Calgary Centre-North/Calgary-Centre-Nord
    "Calgary South Centre/Calgary-Centre-Sud": 48006,  # Renamed to Calgary Centre
    "Edmonton--Beaumont": 48011,  # Edmonton--Mill Woods--Beaumont
    "Dewdney--Alouette": 59007,  # Renamed to Pitt Meadows--Maple Ridge--Mission
    "Kamloops--Thompson": 59010,  # Kamloops--Thompson--Cariboo
    "Kelowna": 59011,  # Kelowna--Lake Country
}

# mask and replace
mask = election_outcomes_38_df['ED_CODE'].isna()
election_outcomes_38_df.loc[mask, 'ED_CODE'] = election_outcomes_38_df.loc[mask, 'Electoral District/Circonscription'].map(missing_codes_map)

# do a double check
election_outcomes_38_df[election_outcomes_38_df['ED_CODE'].isna()]

#election_outcomes_38_df[election_outcomes_38_df['ED_CODE'].isna()]['Electoral District/Circonscription'].unique()
# Out:
# Empty DataFrame
# Columns: [Province, Electoral District/Circonscription, Candidate/Candidat, Candidate Residence/Résidence du candidat, Candidate Occupation/Profession du candidat, Votes Obtained/Votes obtenus, Percentage of Votes Obtained /Pourcentage des votes obtenus, Majority/Majorité, Majority Percentage/Pourcentage de majorité, cleaned_district_name, ED_CODE]
# Index: []

# %%
# preprocess the outcomes
election_outcomes_38_df = add_drop_cols(election_outcomes_38_df)
election_outcomes_38_df['ED_CODE'] = election_outcomes_38_df['ED_CODE'].astype(int)
election_outcomes_38_df['Candidate Name'] = election_outcomes_38_df['Candidate/Candidat'].apply(lambda x: get_candidate_names(x, parties_list))

# check for missing candidates
election_outcomes_38_df[election_outcomes_38_df['Candidate Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District/Circonscription, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, cleaned_district_name, ED_CODE, won_election, Candidate Name]
# Index: []

# %%
# split the candidate names
election_outcomes_38_df[['Recipient first name', 'Recipient last name']] = election_outcomes_38_df['Candidate Name'].apply(split_name)

# check for any missing last names
election_outcomes_38_df[election_outcomes_38_df['Recipient last name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District/Circonscription, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, cleaned_district_name, ED_CODE, won_election, Candidate Name, Recipient first name, Recipient last name]
# Index: []

# %%
# merge with the outcomes
election_38_df = merge_elections(election_contributions_38_df, election_outcomes_38_df)
election_38_df.to_csv('data/merged/38_general_election.csv')
election_38_df
# Out:
#       Political Entity  Recipient ID             Recipient  \
# 0          ﻿Candidates          4716  Béchard, Bruno-Marie
# 1           Candidates          4716  Béchard, Bruno-Marie
# 2           Candidates          4716  Béchard, Bruno-Marie
# 3           Candidates          4716  Béchard, Bruno-Marie
# 4           Candidates          4716  Béchard, Bruno-Marie
# ...                ...           ...                   ...
# 18501       Candidates          5250         Carter, Roger
# 18502       Candidates          5615     Giguère, Philippe
# 18503       Candidates          5141        Morrison, Dean
# 18504       Candidates          4549        Paradis, Denis
# 18505       Candidates          4576        Gougeon, Roger
#
#       Recipient last name Recipient first name  \
# 0                 Béchard          Bruno-Marie
# 1                 Béchard          Bruno-Marie
# 2                 Béchard          Bruno-Marie
# 3                 Béchard          Bruno-Marie
# 4                 Béchard          Bruno-Marie
# ...                   ...                  ...
# 18501              Carter                Roger
# 18502             Giguère             Philippe
# 18503            Morrison                 Dean
# 18504             Paradis                Denis
# 18505             Gougeon                Roger
#
#            Political Party of Recipient  Electoral District  \
# 0               Liberal Party of Canada          Sherbrooke
# 1               Liberal Party of Canada          Sherbrooke
# 2               Liberal Party of Canada          Sherbrooke
# 3               Liberal Party of Canada          Sherbrooke
# 4               Liberal Party of Canada          Sherbrooke
# ...                                 ...                 ...
# 18501  Marxist-Leninist Party of Canada  Beaches--East York
# 18502              New Democratic Party              Beauce
# 18503              New Democratic Party             Langley
# 18504           Liberal Party of Canada   Brome--Missisquoi
# 18505           Liberal Party of Canada            Drummond
#
#              Electoral event Fiscal/Election date Contributor City  \
# 0      38th general election           2004-06-28            Magog
# 1      38th general election           2004-06-28       Sherbrooke
# 2      38th general election           2004-06-28            Ascot
# 3      38th general election           2004-06-28        Shebrooke
# 4      38th general election           2004-06-28         Katevale
# ...                      ...                  ...              ...
# 18501  38th general election           2004-06-28              NaN
# 18502  38th general election           2004-06-28              NaN
# 18503  38th general election           2004-06-28              NaN
# 18504  38th general election           2004-06-28              NaN
# 18505  38th general election           2004-06-28              NaN
#
#       Contributor Province Contributor Postal code Contribution Received date  \
# 0                       QC                 J1X 2C3                        NaN
# 1                       QC                 J1L 2B6                        NaN
# 2                       QC                 J1K 3B4                        NaN
# 3                       QC                 J1H 4J9                        NaN
# 4                       QC                 J0B 1W0                        NaN
# ...                    ...                     ...                        ...
# 18501                  NaN                     NaN                        NaN
# 18502                  NaN                     NaN                        NaN
# 18503                  NaN                     NaN                        NaN
# 18504                  NaN                     NaN                        NaN
# 18505                  NaN                     NaN                        NaN
#
#        Monetary amount cleaned_district_name_x  ED_CODE  \
# 0                400.0              sherbrooke  24070.0
# 1                500.0              sherbrooke  24070.0
# 2                500.0              sherbrooke  24070.0
# 3               2500.0              sherbrooke  24070.0
# 4                500.0              sherbrooke  24070.0
# ...                ...                     ...      ...
# 18501              0.0      beaches  east york  35005.0
# 18502             75.0                  beauce  24005.0
# 18503              0.0                 langley  59013.0
# 18504              0.0       brome  missisquoi  24010.0
# 18505            200.0                drummond  24018.0
#
#        Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0                                                  31.01
# 1                                                  31.01
# 2                                                  31.01
# 3                                                  31.01
# 4                                                  31.01
# ...                                                  ...
# 18501                                               0.10
# 18502                                               3.05
# 18503                                              16.75
# 18504                                              42.08
# 18505                                              22.81
#
#        won_election
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 18501         False
# 18502         False
# 18503         False
# 18504          True
# 18505         False
#
# [18506 rows x 18 columns]

# %% [markdown]
# #### 39th Election

# %%
# grab the relevant data frames
election_contributions_39_df = pd.read_csv('data/contributions/general_elections/39th general election.csv')
election_outcomes_39_df = pd.read_csv('data/stats_can_general_elections/39_general_election_12.csv', encoding = 'latin-1')

# %%
# 39th election needs an additional merge to pick up the ED CODES
election_outcomes_39_df['cleaned_district_name'] = election_outcomes_39_df['Electoral District/Circonscription'].apply(clean_text)
election_outcomes_39_df = election_outcomes_39_df.merge(earlier_district_codes_df[['cleaned_district_name', 'ED_CODE']].copy(), on= 'cleaned_district_name', how='left')

election_outcomes_39_df
# Out:
#                                                Province  \
# 0     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 1     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 2     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 3     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# 4     Newfoundland and Labrador/Terre-Neuve-et-Labrador
# ...                                                 ...
# 1629                                            Nunavut
# 1630                                            Nunavut
# 1631                                            Nunavut
# 1632                                            Nunavut
# 1633                                            Nunavut
#
#            Electoral District/Circonscription  \
# 0                                      Avalon
# 1                                      Avalon
# 2                                      Avalon
# 3                                      Avalon
# 4     Bonavista--Gander--Grand Falls--Windsor
# ...                                       ...
# 1629                                  Nunavut
# 1630                                  Nunavut
# 1631                                  Nunavut
# 1632                                  Nunavut
# 1633                                  Nunavut
#
#                                  Candidate/Candidat  \
# 0          Fabian Manning Conservative/Conservateur
# 1                       Bill Morrow Liberal/Libéral
# 2                       Eugene Conway N.D.P./N.P.D.
# 3            Shannon Hillier Green Party/Parti Vert
# 4                    Scott Simms ** Liberal/Libéral
# ...                                             ...
# 1629       Nancy Karetak-Lindell ** Liberal/Libéral
# 1630   David Aglukark Sr. Conservative/Conservateur
# 1631                     Bill Riddell N.D.P./N.P.D.
# 1632  D. Ed deVries Marijuana Party/Parti Marijuana
# 1633            Feliks Kappi Green Party/Parti Vert
#
#      Candidate Residence/Résidence du candidat  \
# 0                   St. Bride's, N.L./T.-N.-L.
# 1                   Bay Roberts, N.L./T.-N.-L.
# 2            Conception Harbour, N.L./T.-N.-L.
# 3                    St. John's, N.L./T.-N.-L.
# 4                Bishop's Falls, N.L./T.-N.-L.
# ...                                        ...
# 1629                           Arviat, Nun./Nt
# 1630                           Arviat, Nun./Nt
# 1631                          Iqaluit, Nun./Nt
# 1632                          Iqaluit, Nun./Nt
# 1633                     Rankin Inlet, Nun./Nt
#
#          Candidate Occupation/Profession du candidat  \
# 0                      Parliamentarian/Parlementaire
# 1                                      Lawyer/Avocat
# 2           Business Owner/Propriétaire d'entreprise
# 3     Provincial Organizer/Organisatrice provinciale
# 4                      Parliamentarian/Parlementaire
# ...                                              ...
# 1629                   Parliamentarian/Parlementaire
# 1630           Self-employed/Travailleur indépendant
# 1631                           Consultant/Consultant
# 1632      Traditional Healer/Guérisseur traditionnel
# 1633                                Student/Étudiant
#
#       Votes Obtained/Votes obtenus  \
# 0                            19132
# 1                            14318
# 2                             3365
# 3                              297
# 4                            19866
# ...                            ...
# 1629                          3673
# 1630                          2670
# 1631                          1576
# 1632                           724
# 1633                           544
#
#       Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0                                                 51.55
# 1                                                 38.58
# 2                                                  9.07
# 3                                                  0.80
# 4                                                 52.04
# ...                                                 ...
# 1629                                              39.98
# 1630                                              29.06
# 1631                                              17.15
# 1632                                               7.88
# 1633                                               5.92
#
#       Majority/Majorité  Majority Percentage/Pourcentage de majorité  \
# 0                4814.0                                         13.0
# 1                   NaN                                          NaN
# 2                   NaN                                          NaN
# 3                   NaN                                          NaN
# 4                4490.0                                         11.8
# ...                 ...                                          ...
# 1629             1003.0                                         10.9
# 1630                NaN                                          NaN
# 1631                NaN                                          NaN
# 1632                NaN                                          NaN
# 1633                NaN                                          NaN
#
#                         cleaned_district_name  ED_CODE
# 0                                      avalon    10001
# 1                                      avalon    10001
# 2                                      avalon    10001
# 3                                      avalon    10001
# 4     bonavista  gander  grand falls  windsor    10002
# ...                                       ...      ...
# 1629                                  nunavut    62001
# 1630                                  nunavut    62001
# 1631                                  nunavut    62001
# 1632                                  nunavut    62001
# 1633                                  nunavut    62001
#
# [1634 rows x 11 columns]

# %%
# catch any missing district codes
election_outcomes_39_df[election_outcomes_39_df['ED_CODE'].isna()]
# Out:
# Empty DataFrame
# Columns: [Province, Electoral District/Circonscription, Candidate/Candidat, Candidate Residence/Résidence du candidat, Candidate Occupation/Profession du candidat, Votes Obtained/Votes obtenus, Percentage of Votes Obtained /Pourcentage des votes obtenus, Majority/Majorité, Majority Percentage/Pourcentage de majorité, cleaned_district_name, ED_CODE]
# Index: []

# %%
# preprocess the outcomes
election_outcomes_39_df = add_drop_cols(election_outcomes_39_df)
election_outcomes_39_df['ED_CODE'] = election_outcomes_39_df['ED_CODE'].astype(int)
election_outcomes_39_df['Candidate Name'] = election_outcomes_39_df['Candidate/Candidat'].apply(lambda x: get_candidate_names(x, parties_list))

# check for missing candidates
election_outcomes_39_df[election_outcomes_39_df['Candidate Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District/Circonscription, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, cleaned_district_name, ED_CODE, won_election, Candidate Name]
# Index: []

# %%
# split the candidate names
election_outcomes_39_df[['Recipient first name', 'Recipient last name']] = election_outcomes_39_df['Candidate Name'].apply(split_name)

# check for any missing last names
election_outcomes_39_df[election_outcomes_39_df['Recipient last name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District/Circonscription, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, cleaned_district_name, ED_CODE, won_election, Candidate Name, Recipient first name, Recipient last name]
# Index: []

# %%
# merge with the outcomes
election_39_df = merge_elections(election_contributions_39_df, election_outcomes_39_df)
election_39_df.to_csv('data/merged/39_general_election.csv')
election_39_df
# Out:
#       Political Entity  Recipient ID           Recipient Recipient last name  \
# 0           Candidates          8865        Watson, Jeff              Watson
# 1           Candidates          8865        Watson, Jeff              Watson
# 2           Candidates          8865        Watson, Jeff              Watson
# 3           Candidates          8865        Watson, Jeff              Watson
# 4           Candidates          8865        Watson, Jeff              Watson
# ...                ...           ...                 ...                 ...
# 21577       Candidates          8707     Fornssler, Mike           Fornssler
# 21578       Candidates          9140         Maddin, Jim              Maddin
# 21579       Candidates          9106    Maundcote, Paula           Maundcote
# 21580       Candidates          8078       Cardin, Serge              Cardin
# 21581       Candidates          8045  Niziblian, Apraham           Niziblian
#
#       Recipient first name  Political Party of Recipient  \
# 0                     Jeff  Conservative Party of Canada
# 1                     Jeff  Conservative Party of Canada
# 2                     Jeff  Conservative Party of Canada
# 3                     Jeff  Conservative Party of Canada
# 4                     Jeff  Conservative Party of Canada
# ...                    ...                           ...
# 21577                 Mike         Green Party of Canada
# 21578                  Jim          New Democratic Party
# 21579                Paula          New Democratic Party
# 21580                Serge                Bloc Québécois
# 21581              Apraham                Bloc Québécois
#
#           Electoral District        Electoral event Fiscal/Election date  \
# 0                      Essex  39th general election           2006-01-23
# 1                      Essex  39th general election           2006-01-23
# 2                      Essex  39th general election           2006-01-23
# 3                      Essex  39th general election           2006-01-23
# 4                      Essex  39th general election           2006-01-23
# ...                      ...                    ...                  ...
# 21577             Blackstrap  39th general election           2006-01-23
# 21578  Saskatoon--Wanuskewin  39th general election           2006-01-23
# 21579               Shefford  39th general election           2006-01-23
# 21580             Sherbrooke  39th general election           2006-01-23
# 21581               Bourassa  39th general election           2006-01-23
#
#       Contributor City Contributor Province Contributor Postal code  \
# 0            Westmount                   QC                 H3Y 1E9
# 1              Toronto                   ON                 M4T 2S3
# 2              Toronto                   ON                 M5P 2P8
# 3              Toronto                   ON                 M5N 1R5
# 4              Toronto                   ON                 M3H 5S4
# ...                ...                  ...                     ...
# 21577              NaN                  NaN                     NaN
# 21578              NaN                  NaN                     NaN
# 21579              NaN                  NaN                     NaN
# 21580              NaN                  NaN                     NaN
# 21581              NaN                  NaN                     NaN
#
#       Contribution Received date  Monetary amount cleaned_district_name_x  \
# 0                     2006-01-20            500.0                   essex
# 1                     2006-01-20            500.0                   essex
# 2                     2006-01-20            250.0                   essex
# 3                     2006-01-20           1000.0                   essex
# 4                     2006-01-20            750.0                   essex
# ...                          ...              ...                     ...
# 21577                        NaN              0.0              blackstrap
# 21578                        NaN              0.0   saskatoon  wanuskewin
# 21579                        NaN              0.0                shefford
# 21580                        NaN              0.0              sherbrooke
# 21581                        NaN            200.0                bourassa
#
#        ED_CODE  Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0      35021.0                                              40.40
# 1      35021.0                                              40.40
# 2      35021.0                                              40.40
# 3      35021.0                                              40.40
# 4      35021.0                                              40.40
# ...        ...                                                ...
# 21577  47002.0                                               3.29
# 21578  47011.0                                              22.09
# 21579  24069.0                                               4.73
# 21580  24070.0                                              52.20
# 21581  24009.0                                              31.97
#
#        won_election
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 21577         False
# 21578         False
# 21579         False
# 21580          True
# 21581         False
#
# [21582 rows x 18 columns]

# %% [markdown]
# #### 40th Election

# %%
# grab the data frames
election_contributions_40_df = pd.read_csv('data/contributions/general_elections/40th general election.csv')
election_outcomes_40_df = pd.read_csv('data/stats_can_general_elections/40_general_election_12.csv', encoding = 'latin-1')

# %%
# preprocess the outcomes
# update the electoral district rename
election_outcomes_40_df.rename(columns={"Electoral District Number/Numéro de circonscription": "ED_CODE"}, inplace= True)
election_outcomes_40_df = add_drop_cols(election_outcomes_40_df)
election_outcomes_40_df['ED_CODE'] = election_outcomes_40_df['ED_CODE'].astype(int)
election_outcomes_40_df['Candidate Name'] = election_outcomes_40_df['Candidate/Candidat'].apply(lambda x: get_candidate_names(x, parties_list))

# check for missing candidates
election_outcomes_40_df[election_outcomes_40_df['Candidate Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name]
# Index: []

# %%
# split the candidate names
election_outcomes_40_df[['Recipient first name', 'Recipient last name']] = election_outcomes_40_df['Candidate Name'].apply(split_name)

# check for any missing last names
election_outcomes_40_df[election_outcomes_40_df['Recipient last name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name, Recipient first name, Recipient last name]
# Index: []

# %%
# merge with the outcomes
election_40_df = merge_elections(election_contributions_40_df, election_outcomes_40_df)
election_40_df.to_csv('data/merged/40_general_election.csv')
election_40_df
# Out:
#       Political Entity  Recipient ID             Recipient  \
# 0           Candidates         15343         McQuail, Tony
# 1           Candidates         15343         McQuail, Tony
# 2           Candidates         15343         McQuail, Tony
# 3           Candidates         15343         McQuail, Tony
# 4           Candidates         15343         McQuail, Tony
# ...                ...           ...                   ...
# 14349       Candidates         16483  Côrriveau, Sébastien
# 14350       Candidates         16592            Stone, Ray
# 14351       Candidates         16556      Aitchison, Betty
# 14352       Candidates         15096        Komlosy, André
# 14353       Candidates         15142       Boucher, Sylvie
#
#       Recipient last name Recipient first name  Political Party of Recipient  \
# 0                 McQuail                 Tony          New Democratic Party
# 1                 McQuail                 Tony          New Democratic Party
# 2                 McQuail                 Tony          New Democratic Party
# 3                 McQuail                 Tony          New Democratic Party
# 4                 McQuail                 Tony          New Democratic Party
# ...                   ...                  ...                           ...
# 14349           Côrriveau            Sébastien        Parti Rhinocéros Party
# 14350               Stone                  Ray          New Democratic Party
# 14351           Aitchison                Betty       Liberal Party of Canada
# 14352             Komlosy                André  Conservative Party of Canada
# 14353             Boucher               Sylvie  Conservative Party of Canada
#
#            Electoral District        Electoral event Fiscal/Election date  \
# 0                Huron--Bruce  40th general election           2008-10-14
# 1                Huron--Bruce  40th general election           2008-10-14
# 2                Huron--Bruce  40th general election           2008-10-14
# 3                Huron--Bruce  40th general election           2008-10-14
# 4                Huron--Bruce  40th general election           2008-10-14
# ...                       ...                    ...                  ...
# 14349              Sherbrooke  40th general election           2008-10-14
# 14350  Vegreville--Wainwright  40th general election           2008-10-14
# 14351      Kootenay--Columbia  40th general election           2008-10-14
# 14352                Drummond  40th general election           2008-10-14
# 14353      Beauport--Limoilou  40th general election           2008-10-14
#
#       Contributor City Contributor Province Contributor Postal code  \
# 0              Clinton                   ON                 NOM 1L0
# 1             Goderich                   ON                 N7A 3Y1
# 2             Bayfield                   ON                 N0M 1G0
# 3           Kincardine                   ON                 N2Z 2X3
# 4              Lucknow                   ON                 N0G 2H0
# ...                ...                  ...                     ...
# 14349              NaN                  NaN                     NaN
# 14350              NaN                  NaN                     NaN
# 14351              NaN                  NaN                     NaN
# 14352              NaN                  NaN                     NaN
# 14353              NaN                  NaN                     NaN
#
#       Contribution Received date  Monetary amount   cleaned_district_name  \
# 0                     2008-10-03            400.0            huron  bruce
# 1                     2008-10-03            300.0            huron  bruce
# 2                     2008-10-14            400.0            huron  bruce
# 3                     2008-10-14            250.0            huron  bruce
# 4                     2008-10-14            500.0            huron  bruce
# ...                          ...              ...                     ...
# 14349                        NaN            180.0              sherbrooke
# 14350                        NaN            126.0  vegreville  wainwright
# 14351                        NaN            400.0      kootenay  columbia
# 14352                        NaN              0.0                drummond
# 14353                        NaN            250.0      beauport  limoilou
#
#        ED_CODE  Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0      35034.0                                              14.99
# 1      35034.0                                              14.99
# 2      35034.0                                              14.99
# 3      35034.0                                              14.99
# 4      35034.0                                              14.99
# ...        ...                                                ...
# 14349  24070.0                                               0.92
# 14350  48024.0                                               9.45
# 14351  59012.0                                               7.75
# 14352  24018.0                                              25.31
# 14353  24007.0                                              36.76
#
#        won_election
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 14349         False
# 14350         False
# 14351         False
# 14352         False
# 14353          True
#
# [14354 rows x 18 columns]

# %% [markdown]
# #### 41st Election

# %%
# grab the data frames
election_contributions_41_df = pd.read_csv('data/contributions/general_elections/41st general election.csv')
election_outcomes_41_df = pd.read_csv('data/stats_can_general_elections/41_general_election_12.csv', encoding = 'latin-1')

# %%
# preprocess the outcomes
# update the electoral district rename
election_outcomes_41_df.rename(columns={"Electoral District Number/Numéro de circonscription": "ED_CODE"}, inplace= True)
election_outcomes_41_df = add_drop_cols(election_outcomes_41_df)
election_outcomes_41_df['ED_CODE'] = election_outcomes_41_df['ED_CODE'].astype(int)
election_outcomes_41_df['Candidate Name'] = election_outcomes_41_df['Candidate/Candidat'].apply(lambda x: get_candidate_names(x, parties_list))

# check for missing candidates
election_outcomes_41_df[election_outcomes_41_df['Candidate Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name]
# Index: []

# %%
# split the candidate names
election_outcomes_41_df[['Recipient first name', 'Recipient last name']] = election_outcomes_41_df['Candidate Name'].apply(split_name)

# check for any missing last names
election_outcomes_41_df[election_outcomes_41_df['Recipient last name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name, Recipient first name, Recipient last name]
# Index: []

# %%
# merge with the outcomes
election_41_df = merge_elections(election_contributions_41_df, election_outcomes_41_df)
election_41_df.to_csv('data/merged/41_general_election.csv')
election_41_df
# Out:
#       Political Entity  Recipient ID             Recipient  \
# 0           Candidates         21677         Easter, Wayne
# 1           Candidates         21677         Easter, Wayne
# 2           Candidates         21677         Easter, Wayne
# 3           Candidates         21677         Easter, Wayne
# 4           Candidates         21677         Easter, Wayne
# ...                ...           ...                   ...
# 12474       Candidates         22819        Barney, Rachel
# 12475       Candidates         22791  Lescarbeau, Nicholas
# 12476       Candidates         22634     Belanger, Matthew
# 12477       Candidates         23019  Schellenberg, Konrad
# 12478       Candidates         22267      Darnell, Rebecca
#
#       Recipient last name Recipient first name Political Party of Recipient  \
# 0                  Easter                Wayne      Liberal Party of Canada
# 1                  Easter                Wayne      Liberal Party of Canada
# 2                  Easter                Wayne      Liberal Party of Canada
# 3                  Easter                Wayne      Liberal Party of Canada
# 4                  Easter                Wayne      Liberal Party of Canada
# ...                   ...                  ...                          ...
# 12474              Barney               Rachel        Green Party of Canada
# 12475          Lescarbeau             Nicholas        Green Party of Canada
# 12476            Belanger              Matthew  Libertarian Party of Canada
# 12477        Schellenberg               Konrad        Green Party of Canada
# 12478             Darnell              Rebecca      Liberal Party of Canada
#
#       Electoral District        Electoral event Fiscal/Election date  \
# 0               Malpeque  41st general election           2011-05-02
# 1               Malpeque  41st general election           2011-05-02
# 2               Malpeque  41st general election           2011-05-02
# 3               Malpeque  41st general election           2011-05-02
# 4               Malpeque  41st general election           2011-05-02
# ...                  ...                    ...                  ...
# 12474   Trinity--Spadina  41st general election           2011-05-02
# 12475   Chambly--Borduas  41st general election           2011-05-02
# 12476             Oshawa  41st general election           2011-05-02
# 12477           Crowfoot  41st general election           2011-05-02
# 12478            Langley  41st general election           2011-05-02
#
#       Contributor City Contributor Province Contributor Postal code  \
# 0             Cornwall                   PE                  C0A1H0
# 1      North Wiltshire                   PE                  C0A1Y0
# 2      North Wiltshire                   PE                  C0A1Y0
# 3        Charlottetown                   PE                  C1A7J7
# 4        Charlottetown                   PE                  C1A8C3
# ...                ...                  ...                     ...
# 12474              NaN                  NaN                     NaN
# 12475              NaN                  NaN                     NaN
# 12476              NaN                  NaN                     NaN
# 12477              NaN                  NaN                     NaN
# 12478              NaN                  NaN                     NaN
#
#       Contribution Received date  Monetary amount cleaned_district_name  \
# 0                     2011-04-04           1100.0              malpeque
# 1                     2011-04-12            400.0              malpeque
# 2                     2011-04-12            400.0              malpeque
# 3                     2011-04-29            500.0              malpeque
# 4                     2011-04-14            300.0              malpeque
# ...                          ...              ...                   ...
# 12474                        NaN            550.0      trinity  spadina
# 12475                        NaN             10.0      chambly  borduas
# 12476                        NaN              0.0                oshawa
# 12477                        NaN              0.0              crowfoot
# 12478                        NaN            100.0               langley
#
#        ED_CODE  Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0      11004.0                                               42.4
# 1      11004.0                                               42.4
# 2      11004.0                                               42.4
# 3      11004.0                                               42.4
# 4      11004.0                                               42.4
# ...        ...                                                ...
# 12474  35095.0                                                4.4
# 12475  24012.0                                                1.5
# 12476  35061.0                                                0.5
# 12477  48010.0                                                3.3
# 12478  59013.0                                                9.1
#
#        won_election
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 12474         False
# 12475         False
# 12476         False
# 12477         False
# 12478         False
#
# [12479 rows x 18 columns]

# %% [markdown]
# #### 42nd Election

# %%
# grab the data frames
election_contributions_42_df = pd.read_csv('data/contributions/general_elections/42nd general election.csv')
election_outcomes_42_df = pd.read_csv('data/stats_can_general_elections/42_general_election_12.csv')

# %%
# preprocess the outcomes
# update the electoral district rename
election_outcomes_42_df.rename(columns={"Electoral District Number/Numéro de circonscription": "ED_CODE"}, inplace= True)
election_outcomes_42_df = add_drop_cols(election_outcomes_42_df)
election_outcomes_42_df['ED_CODE'] = election_outcomes_42_df['ED_CODE'].astype(int)
election_outcomes_42_df['Candidate Name'] = election_outcomes_42_df['Candidate/Candidat'].apply(lambda x: get_candidate_names(x, parties_list))

# check for missing candidates
election_outcomes_42_df[election_outcomes_42_df['Candidate Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name]
# Index: []

# %%
# split the candidate names
election_outcomes_42_df[['Recipient first name', 'Recipient last name']] = election_outcomes_42_df['Candidate Name'].apply(split_name)

# check for any missing last names
election_outcomes_42_df[election_outcomes_42_df['Recipient last name'].isna()]
# Out:
#          Electoral District Name/Nom de circonscription  ED_CODE  \
# 5                                                Avalon    10001
# 174                Avignon--La Mitis--Matane--Matapédia    24006
# 188   Beauport--Côte-de-Beaupré--Île d'Orléans--Char...    24020
# 196                                  Beauport--Limoilou    24008
# 225                                            Bourassa    24015
# 231                                   Brome--Missisquoi    24016
# 296                                      Honoré-Mercier    24029
# 311                                            Joliette    24031
# 324                                  La Pointe-de-l'Île    24033
# 385                             Longueuil--Saint-Hubert    24043
# 428                                            Montcalm    24050
# 480                                             Pontiac    24057
# 493                                              Québec    24059
# 498                                          Repentigny    24060
# 567                                   Salaberry--Suroît    24071
# 585                                          Terrebonne    24075
# 1058                             Peterborough--Kawartha    35084
# 1766                      Vancouver South/Vancouver-Sud    59040
#
#                                      Candidate/Candidat  \
# 5     Jennifer McCreath Forces et Démocratie - Allie...
# 174   Jean-François Fortin ** Forces et Démocratie -...
# 188   Mario Desjardins Pelchat Forces et Démocratie ...
# 196   Bladimir Laborit Forces et Démocratie - Allier...
# 225   Jean-Marie Floriant Ndzana Forces et Démocrati...
# 231   Patrick Paine Forces et Démocratie - Allier le...
# 296   Dayana Dejean Forces et Démocratie - Allier le...
# 311   Robert D. Morais Forces et Démocratie - Allier...
# 324   Jean-François Larose Forces et Démocratie - Al...
# 385   Affine Lwalalika Forces et Démocratie - Allier...
# 428   Manon Perreault ** Forces et Démocratie - Alli...
# 480   Pascal Médieu Forces et Démocratie - Allier le...
# 493   Danielle Provost Forces et Démocratie - Allier...
# 498   Johnathan Cloutier Forces et Démocratie - Alli...
# 567   Patricia Domingos Forces et Démocratie - Allie...
# 585   Louis Clément Sénat Forces et Démocratie - All...
# 1058  Toban Leckie Forces et Démocratie - Allier les...
# 1766                        Raj Gupta PC Party/Parti PC
#
#       Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 5                                                   0.2
# 174                                                11.6
# 188                                                 0.4
# 196                                                 0.2
# 225                                                 0.2
# 231                                                 0.3
# 296                                                 0.3
# 311                                                 0.4
# 324                                                 0.2
# 385                                                 0.3
# 428                                                 1.2
# 480                                                 0.2
# 493                                                 0.2
# 498                                                 2.0
# 567                                                 0.3
# 585                                                 0.3
# 1058                                                0.2
# 1766                                                0.4
#
#       won_election Candidate Name Recipient first name Recipient last name
# 5            False       Jennifer             Jennifer                None
# 174          False  Jean-François        Jean-François                None
# 188          False          Mario                Mario                None
# 196          False       Bladimir             Bladimir                None
# 225          False     Jean-Marie           Jean-Marie                None
# 231          False        Patrick              Patrick                None
# 296          False         Dayana               Dayana                None
# 311          False         Robert               Robert                None
# 324          False  Jean-François        Jean-François                None
# 385          False         Affine               Affine                None
# 428          False          Manon                Manon                None
# 480          False         Pascal               Pascal                None
# 493          False       Danielle             Danielle                None
# 498          False      Johnathan            Johnathan                None
# 567          False       Patricia             Patricia                None
# 585          False          Louis                Louis                None
# 1058         False          Toban                Toban                None
# 1766         False            Raj                  Raj                None

# %%
missing_last_name_map = {
    "Jennifer McCreath Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "McCreath",
    "Jean-François Fortin ** Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Fortin",
    "Mario Desjardins Pelchat Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Pelchat",
    "Bladimir Laborit Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Laborit",
    "Jean-Marie Floriant Ndzana Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Ndzana",
    "Patrick Paine Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Paine",
    "Dayana Dejean Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Dejean",
    "Robert D. Morais Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Morais",
    "Jean-François Larose Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Larose",
    "Affine Lwalalika Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Lwalalika",
    "Manon Perreault ** Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Perreault",
    "Pascal Médieu Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Médieu",
    "Danielle Provost Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Provost",
    "Johnathan Cloutier Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Cloutier",
    "Patricia Domingos Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Domingos",
    "Louis Clément Sénat Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Sénat",
    "Toban Leckie Forces et Démocratie - Allier les forces de nos régions/Forces et Démocratie - Allier les forces de nos régions": "Leckie",
    "Raj Gupta PC Party/Parti PC": "Gupta"
}

mask = election_outcomes_42_df['Recipient last name'].isna()
election_outcomes_42_df.loc[mask, 'Recipient last name'] = election_outcomes_42_df.loc[mask, 'Candidate/Candidat'].map(missing_last_name_map)

# check again
election_outcomes_42_df[election_outcomes_42_df['Recipient last name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name, Recipient first name, Recipient last name]
# Index: []

# %%
# merge with the outcomes
election_42_df = merge_elections(election_contributions_42_df, election_outcomes_42_df)
election_42_df.to_csv('data/merged/42_general_election.csv')
election_42_df
# Out:
#       Political Entity  Recipient ID            Recipient Recipient last name  \
# 0          ﻿Candidates         30603          Begg, Garry                Begg
# 1           Candidates         30603          Begg, Garry                Begg
# 2           Candidates         30603          Begg, Garry                Begg
# 3           Candidates         30603          Begg, Garry                Begg
# 4           Candidates         30603          Begg, Garry                Begg
# ...                ...           ...                  ...                 ...
# 18496       Candidates         30537           Albas, Dan               Albas
# 18497       Candidates         30399         Quimpo, Jojo              Quimpo
# 18498       Candidates         32532     Gaudreau, Daniel            Gaudreau
# 18499       Candidates         30463  Catellier, François           Catellier
# 18500       Candidates         30874    Moriarity, Andrew           Moriarity
#
#       Recipient first name        Political Party of Recipient  \
# 0                    Garry                New Democratic Party
# 1                    Garry                New Democratic Party
# 2                    Garry                New Democratic Party
# 3                    Garry                New Democratic Party
# 4                    Garry                New Democratic Party
# ...                    ...                                 ...
# 18496                  Dan        Conservative Party of Canada
# 18497                 Jojo        Conservative Party of Canada
# 18498               Daniel        Conservative Party of Canada
# 18499             François        Conservative Party of Canada
# 18500               Andrew  Christian Heritage Party of Canada
#
#                           Electoral District        Electoral event  \
# 0                      Fleetwood--Port Kells  42nd general election
# 1                      Fleetwood--Port Kells  42nd general election
# 2                      Fleetwood--Port Kells  42nd general election
# 3                      Fleetwood--Port Kells  42nd general election
# 4                      Fleetwood--Port Kells  42nd general election
# ...                                      ...                    ...
# 18496  Central Okanagan--Similkameen--Nicola  42nd general election
# 18497                     Vancouver Kingsway  42nd general election
# 18498                  Laurier--Sainte-Marie  42nd general election
# 18499            Saint Boniface--Saint Vital  42nd general election
# 18500                                 Durham  42nd general election
#
#       Fiscal/Election date Contributor City Contributor Province  \
# 0               2015-10-19           Surrey                   BC
# 1               2015-10-19           Surrey                   BC
# 2               2015-10-19           Surrey                   BC
# 3               2015-10-19           Surrey                   BC
# 4               2015-10-19           Surrey                   BC
# ...                    ...              ...                  ...
# 18496           2015-10-19              NaN                  NaN
# 18497           2015-10-19              NaN                  NaN
# 18498           2015-10-19              NaN                  NaN
# 18499           2015-10-19              NaN                  NaN
# 18500           2015-10-19              NaN                  NaN
#
#       Contributor Postal code Contribution Received date  Monetary amount  \
# 0                     V3S 6A3                 2015-10-02           500.00
# 1                      V3S2Z6                 2015-10-09           500.00
# 2                     V3S 0T9                 2015-10-18           500.00
# 3                     V4N 5L7                 2015-10-09           500.00
# 4                      V3S2J2                 2015-10-05           500.00
# ...                       ...                        ...              ...
# 18496                     NaN                        NaN             0.00
# 18497                     NaN                        NaN           731.83
# 18498                     NaN                        NaN           160.00
# 18499                     NaN                        NaN           200.00
# 18500                     NaN                        NaN           125.00
#
#                        cleaned_district_name  ED_CODE  \
# 0                      fleetwood  port kells    59012
# 1                      fleetwood  port kells    59012
# 2                      fleetwood  port kells    59012
# 3                      fleetwood  port kells    59012
# 4                      fleetwood  port kells    59012
# ...                                      ...      ...
# 18496  central okanagan  similkameen  nicola    59005
# 18497                     vancouver kingsway    59038
# 18498                  laurier  sainte marie    24039
# 18499            saint boniface  saint vital    46009
# 18500                                 durham    35023
#
#        Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0                                                   21.5
# 1                                                   21.5
# 2                                                   21.5
# 3                                                   21.5
# 4                                                   21.5
# ...                                                  ...
# 18496                                               39.6
# 18497                                               21.0
# 18498                                                4.1
# 18499                                               28.7
# 18500                                                0.6
#
#        won_election
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 18496          True
# 18497         False
# 18498         False
# 18499         False
# 18500         False
#
# [18501 rows x 18 columns]

# %% [markdown]
# #### 43rd Election

# %%
# grab the data frames
election_contributions_43_df = pd.read_csv('data/contributions/general_elections/43rd general election.csv')
election_outcomes_43_df = pd.read_csv('data/stats_can_general_elections/43_general_election_12.csv')

# %%
# preprocess the outcomes
# update the electoral district rename
election_outcomes_43_df.rename(columns={"Electoral District Number/Numéro de circonscription": "ED_CODE"}, inplace= True)
election_outcomes_43_df = add_drop_cols(election_outcomes_43_df)
election_outcomes_43_df['ED_CODE'] = election_outcomes_43_df['ED_CODE'].astype(int)
election_outcomes_43_df['Candidate Name'] = election_outcomes_43_df['Candidate/Candidat'].apply(lambda x: get_candidate_names(x, parties_list))

# check for missing candidates
election_outcomes_43_df[election_outcomes_43_df['Candidate Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name]
# Index: []

# %%
# split the candidate names
election_outcomes_43_df[['Recipient first name', 'Recipient last name']] = election_outcomes_43_df['Candidate Name'].apply(split_name)

# check for any missing last names
election_outcomes_43_df[election_outcomes_43_df['Recipient last name'].isna()]
# Out:
#      Electoral District Name/Nom de circonscription  ED_CODE  \
# 992                       Humber River--Black Creek    35121
# 1116                         Mississauga--Lakeshore    35061
# 1122                            Mississauga--Malton    35062
# 1318             Scarborough North/Scarborough-Nord    35096
# 2122                                       Victoria    59041
#
#                       Candidate/Candidat  \
# 992               Stenneth Smith UPC/UPC
# 1116               Carlton Darby UPC/UPC
# 1122           Prudence Buchanan UPC/UPC
# 1318              Janet Robinson UPC/UPC
# 2122  Robert Duncan Communist/Communiste
#
#       Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 992                                                 0.3
# 1116                                                0.2
# 1122                                                0.6
# 1318                                                0.2
# 2122                                                0.2
#
#       won_election Candidate Name Recipient first name Recipient last name
# 992          False       Stenneth             Stenneth                None
# 1116         False        Carlton              Carlton                None
# 1122         False       Prudence             Prudence                None
# 1318         False          Janet                Janet                None
# 2122         False         Robert               Robert                None

# %%
# fill in some missing last names
missing_last_name_map = {
    "Stenneth Smith UPC/UPC": "Smith",
    "Carlton Darby UPC/UPC": "Darby",
    "Prudence Buchanan UPC/UPC": "Buchanan",
    "Janet Robinson UPC/UPC": "Robinson",
    "Robert Duncan Communist/Communiste": "Duncan"
}
mask = election_outcomes_43_df['Recipient last name'].isna()
election_outcomes_43_df.loc[mask, 'Recipient last name'] = election_outcomes_43_df.loc[mask, 'Candidate/Candidat'].map(missing_last_name_map)

# check again
election_outcomes_43_df[election_outcomes_43_df['Recipient last name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name, Recipient first name, Recipient last name]
# Index: []

# %%
# merge with the outcomes
election_43_df = merge_elections(election_contributions_43_df, election_outcomes_43_df)
election_43_df.to_csv('data/merged/43_general_election.csv')
election_43_df
# Out:
#     Political Entity  Recipient ID          Recipient Recipient last name  \
# 0         Candidates         42102  Pupatello, Sandra           Pupatello
# 1         Candidates         42102  Pupatello, Sandra           Pupatello
# 2         Candidates         42102  Pupatello, Sandra           Pupatello
# 3         Candidates         42102  Pupatello, Sandra           Pupatello
# 4         Candidates         42102  Pupatello, Sandra           Pupatello
# ..               ...           ...                ...                 ...
# 541       Candidates         41662    Tordjman, David            Tordjman
# 542       Candidates         41662    Tordjman, David            Tordjman
# 543       Candidates         41905   Veilleux, Sophie            Veilleux
# 544       Candidates         41513   Laplante, Hugues            Laplante
# 545       Candidates         41275        Ma, Michael                  Ma
#
#     Recipient first name  Political Party of Recipient    Electoral District  \
# 0                 Sandra       Liberal Party of Canada          Windsor West
# 1                 Sandra       Liberal Party of Canada          Windsor West
# 2                 Sandra       Liberal Party of Canada          Windsor West
# 3                 Sandra       Liberal Party of Canada          Windsor West
# 4                 Sandra       Liberal Party of Canada          Windsor West
# ..                   ...                           ...                   ...
# 541                David  Conservative Party of Canada           Mount Royal
# 542                David  Conservative Party of Canada           Mount Royal
# 543               Sophie  Conservative Party of Canada              Papineau
# 544               Hugues  Conservative Party of Canada  Châteauguay--Lacolle
# 545              Michael  Conservative Party of Canada       Don Valley East
#
#            Electoral event Fiscal/Election date     Contributor City  \
# 0    43rd general election           2019-10-21              WINDSOR
# 1    43rd general election           2019-10-21             TECUMSEH
# 2    43rd general election           2019-10-21           BELLERIVER
# 3    43rd general election           2019-10-21              WINDSOR
# 4    43rd general election           2019-10-21              WINDSOR
# ..                     ...                  ...                  ...
# 541  43rd general election           2019-10-21  Dollard-des-Ormeaux
# 542  43rd general election           2019-10-21                  NaN
# 543  43rd general election           2019-10-21                  NaN
# 544  43rd general election           2019-10-21                  NaN
# 545  43rd general election           2019-10-21                  NaN
#
#     Contributor Province Contributor Postal code Contribution Received date  \
# 0                     ON                  N9E4P5                 2019-10-04
# 1                     ON                  N8N5H1                 2019-09-27
# 2                     ON                  N0R1A0                 2019-10-11
# 3                     ON                  N9E4P5                 2019-10-04
# 4                     ON                  N9E1W1                 2019-09-27
# ..                   ...                     ...                        ...
# 541                   QC                  H9A3G2                 2019-10-20
# 542                  NaN                     NaN                        NaN
# 543                  NaN                     NaN                        NaN
# 544                  NaN                     NaN                        NaN
# 545                  NaN                     NaN                        NaN
#
#      Monetary amount cleaned_district_name  ED_CODE  \
# 0             1600.0          windsor west    35117
# 1              500.0          windsor west    35117
# 2             1600.0          windsor west    35117
# 3             1600.0          windsor west    35117
# 4              500.0          windsor west    35117
# ..               ...                   ...      ...
# 541           1200.0           mount royal    24052
# 542            200.0           mount royal    24052
# 543              0.0              papineau    24055
# 544            840.0  châteauguay  lacolle    24021
# 545            165.0       don valley east    35019
#
#      Percentage of Votes Obtained /Pourcentage des votes obtenus  won_election
# 0                                                 36.3                   False
# 1                                                 36.3                   False
# 2                                                 36.3                   False
# 3                                                 36.3                   False
# 4                                                 36.3                   False
# ..                                                 ...                     ...
# 541                                               24.9                   False
# 542                                               24.9                   False
# 543                                                4.2                   False
# 544                                               11.2                   False
# 545                                               23.9                   False
#
# [546 rows x 18 columns]

# %% [markdown]
# #### 44th Election

# %%
# grab the data frames
election_contributions_44_df = pd.read_csv('data/contributions/general_elections/44th general election.csv')
election_outcomes_44_df = pd.read_csv('data/stats_can_general_elections/44_general_election_12.csv')

# %%
# preprocess the outcomes
# update the electoral district rename
election_outcomes_44_df.rename(columns={"Electoral District Number/Numéro de circonscription": "ED_CODE"}, inplace= True)
election_outcomes_44_df = add_drop_cols(election_outcomes_44_df)
election_outcomes_44_df['ED_CODE'] = election_outcomes_44_df['ED_CODE'].astype(int)
election_outcomes_44_df['Candidate Name'] = election_outcomes_44_df['Candidate/Candidat'].apply(lambda x: get_candidate_names(x, parties_list))

# check for missing candidates
election_outcomes_44_df[election_outcomes_44_df['Candidate Name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name]
# Index: []

# %%
# split the candidate names
election_outcomes_44_df[['Recipient first name', 'Recipient last name']] = election_outcomes_44_df['Candidate Name'].apply(split_name)

# check for any missing last names
election_outcomes_44_df[election_outcomes_44_df['Recipient last name'].isna()]
# Out:
# Empty DataFrame
# Columns: [Electoral District Name/Nom de circonscription, ED_CODE, Candidate/Candidat, Percentage of Votes Obtained /Pourcentage des votes obtenus, won_election, Candidate Name, Recipient first name, Recipient last name]
# Index: []

# %%
# merge with the outcomes
election_44_df = merge_elections(election_contributions_44_df, election_outcomes_44_df)
election_44_df.to_csv('data/merged/44_general_election.csv')
election_44_df
# Out:
#      Political Entity  Recipient ID          Recipient Recipient last name  \
# 0          Candidates         47414         Ward, Jeff                Ward
# 1          Candidates         47414         Ward, Jeff                Ward
# 2          Candidates         47414         Ward, Jeff                Ward
# 3          Candidates         47414         Ward, Jeff                Ward
# 4          Candidates         47414         Ward, Jeff                Ward
# ...               ...           ...                ...                 ...
# 6824       Candidates         47098    Richards, Blake            Richards
# 6825       Candidates         47567      Cook, Anthony                Cook
# 6826       Candidates         47402    Wright, Michael              Wright
# 6827       Candidates         47647      Hickey, Jason              Hickey
# 6828       Candidates         48972  Quinto, Elizabeth              Quinto
#
#      Recipient first name  Political Party of Recipient  \
# 0                    Jeff          New Democratic Party
# 1                    Jeff          New Democratic Party
# 2                    Jeff          New Democratic Party
# 3                    Jeff          New Democratic Party
# 4                    Jeff          New Democratic Party
# ...                   ...                           ...
# 6824                Blake  Conservative Party of Canada
# 6825              Anthony      People's Party of Canada
# 6826              Michael         Green Party of Canada
# 6827                Jason       Liberal Party of Canada
# 6828            Elizabeth       Liberal Party of Canada
#
#            Electoral District        Electoral event Fiscal/Election date  \
# 0            Sydney--Victoria  44th general election           2021-09-20
# 1            Sydney--Victoria  44th general election           2021-09-20
# 2            Sydney--Victoria  44th general election           2021-09-20
# 3            Sydney--Victoria  44th general election           2021-09-20
# 4            Sydney--Victoria  44th general election           2021-09-20
# ...                       ...                    ...                  ...
# 6824           Banff--Airdrie  44th general election           2021-09-20
# 6825          Vancouver South  44th general election           2021-09-20
# 6826           Regina--Lewvan  44th general election           2021-09-20
# 6827  New Brunswick Southwest  44th general election           2021-09-20
# 6828                   Oxford  44th general election           2021-09-20
#
#      Contributor City Contributor Province Contributor Postal code  \
# 0           Membertou                   NS                 B1S 3K8
# 1           Coxhealth                   NS                 B1R 1T8
# 2           Membertou                   NS                 B1S 0K2
# 3          North York                   ON                 M2M 2W2
# 4         Dutch Brook                   NS                 B1L 1E9
# ...               ...                  ...                     ...
# 6824              NaN                  NaN                     NaN
# 6825              NaN                  NaN                     NaN
# 6826              NaN                  NaN                     NaN
# 6827              NaN                  NaN                     NaN
# 6828              NaN                  NaN                     NaN
#
#      Contribution Received date  Monetary amount    cleaned_district_name  \
# 0                    2021-09-08            300.0         sydney  victoria
# 1                    2021-09-05            500.0         sydney  victoria
# 2                    2021-09-15            300.0         sydney  victoria
# 3                    2021-09-11            215.0         sydney  victoria
# 4                    2021-09-19            400.0         sydney  victoria
# ...                         ...              ...                      ...
# 6824                        NaN              0.0           banff  airdrie
# 6825                        NaN             20.0          vancouver south
# 6826                        NaN             30.0           regina  lewvan
# 6827                        NaN             20.0  new brunswick southwest
# 6828                        NaN            500.0                   oxford
#
#       ED_CODE  Percentage of Votes Obtained /Pourcentage des votes obtenus  \
# 0       12010                                               19.9
# 1       12010                                               19.9
# 2       12010                                               19.9
# 3       12010                                               19.9
# 4       12010                                               19.9
# ...       ...                                                ...
# 6824    48001                                               56.7
# 6825    59040                                                2.7
# 6826    47007                                                1.2
# 6827    13008                                               23.9
# 6828    35080                                               20.5
#
#       won_election
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 6824          True
# 6825         False
# 6826         False
# 6827         False
# 6828         False
#
# [6829 rows x 18 columns]
